# %%
# !wget -q https://www.dropbox.com/s/erd3ltod0s0xtk8/RACE.zip
# !unzip -o /content/RACE.zip
# Out:
# 串流輸出內容已截斷至最後 5000 行。
#   inflating: RACE/RACE/train/high/8047.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._8047.txt
#   inflating: RACE/RACE/train/high/15633.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._15633.txt
#   inflating: RACE/RACE/train/high/7374.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._7374.txt
#   inflating: RACE/RACE/train/high/9359.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._9359.txt
#   inflating: RACE/RACE/train/high/291.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._291.txt
#   inflating: RACE/RACE/train/high/1705.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._1705.txt
#   inflating: RACE/RACE/train/high/18317.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._18317.txt
#   inflating: RACE/RACE/train/high/5563.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._5563.txt
#   inflating: RACE/RACE/train/high/20688.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._20688.txt
#   inflating: RACE/RACE/train/high/10993.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._10993.txt
#   inflating: RACE/RACE/train/high/21596.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._21596.txt
#   inflating: RACE/RACE/train/high/11455.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._11455.txt
#   inflating: RACE/RACE/train/high/3112.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._3112.txt
#   inflating: RACE/RACE/train/high/4696.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._4696.txt
#   inflating: RACE/RACE/train/high/10978.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._10978.txt
#   inflating: RACE/RACE/train/high/20663.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._20663.txt
#   inflating: RACE/RACE/train/high/5588.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._5588.txt
#   inflating: RACE/RACE/train/high/15800.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._15800.txt
#   inflating: RACE/RACE/train/high/22074.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._22074.txt
#   inflating: RACE/RACE/train/high/1936.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._1936.txt
#   inflating: RACE/RACE/train/high/22712.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._22712.txt
#   inflating: RACE/RACE/train/high/8912.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._8912.txt
#   inflating: RACE/RACE/train/high/1088.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._1088.txt
#   inflating: RACE/RACE/train/high/3847.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._3847.txt
#   inflating: RACE/RACE/train/high/20105.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._20105.txt
#   inflating: RACE/RACE/train/high/2581.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._2581.txt
#   inflating: RACE/RACE/train/high/17971.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._17971.txt
#   inflating: RACE/RACE/train/high/19784.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._19784.txt
#   inflating: RACE/RACE/train/high/3853.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._3853.txt
#   inflating: RACE/RACE/train/high/19948.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._19948.txt
#   inflating: RACE/RACE/train/high/17965.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._17965.txt
#   inflating: RACE/RACE/train/high/22706.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._22706.txt
#   inflating: RACE/RACE/train/high/508.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._508.txt
#   inflating: RACE/RACE/train/high/8906.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._8906.txt
#   inflating: RACE/RACE/train/high/6095.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._6095.txt
#   inflating: RACE/RACE/train/high/15814.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._15814.txt
#   inflating: RACE/RACE/train/high/1922.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._1922.txt
#   inflating: RACE/RACE/train/high/21569.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._21569.txt
#   inflating: RACE/RACE/train/high/4682.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._4682.txt
#   inflating: RACE/RACE/train/high/20677.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._20677.txt
#   inflating: RACE/RACE/train/high/13295.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._13295.txt
#   inflating: RACE/RACE/train/high/8090.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._8090.txt
#   inflating: RACE/RACE/train/high/11482.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._11482.txt
#   inflating: RACE/RACE/train/high/20887.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._20887.txt
#   inflating: RACE/RACE/train/high/4872.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._4872.txt
#   inflating: RACE/RACE/train/high/17795.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._17795.txt
#   inflating: RACE/RACE/train/high/20139.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._20139.txt
#   inflating: RACE/RACE/train/high/19960.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._19960.txt
#   inflating: RACE/RACE/train/high/21227.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._21227.txt
#   inflating: RACE/RACE/train/high/520.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._520.txt
#   inflating: RACE/RACE/train/high/23430.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._23430.txt
#   inflating: RACE/RACE/train/high/12835.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._12835.txt
#   inflating: RACE/RACE/train/high/15196.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._15196.txt
#   inflating: RACE/RACE/train/high/6917.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._6917.txt
#   inflating: RACE/RACE/train/high/534.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._534.txt
#   inflating: RACE/RACE/train/high/14288.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._14288.txt
#   inflating: RACE/RACE/train/high/23424.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._23424.txt
#   inflating: RACE/RACE/train/high/12821.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._12821.txt
#   inflating: RACE/RACE/train/high/17781.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._17781.txt
#   inflating: RACE/RACE/train/high/21555.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._21555.txt
#   inflating: RACE/RACE/train/high/11496.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._11496.txt
#   inflating: RACE/RACE/train/high/20893.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._20893.txt
#   inflating: RACE/RACE/train/high/4866.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._4866.txt
#   inflating: RACE/RACE/train/high/23342.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._23342.txt
#   inflating: RACE/RACE/train/high/252.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._252.txt
#   inflating: RACE/RACE/train/high/15828.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._15828.txt
#   inflating: RACE/RACE/train/high/13281.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._13281.txt
#   inflating: RACE/RACE/train/high/8084.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._8084.txt
#   inflating: RACE/RACE/train/high/23815.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._23815.txt
#   inflating: RACE/RACE/train/high/12410.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._12410.txt
#   inflating: RACE/RACE/train/high/7638.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._7638.txt
#   inflating: RACE/RACE/train/high/9615.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._9615.txt
#   inflating: RACE/RACE/train/high/14061.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._14061.txt
#   inflating: RACE/RACE/train/high/1249.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._1249.txt
#   inflating: RACE/RACE/train/high/10207.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._10207.txt
#   inflating: RACE/RACE/train/high/2740.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._2740.txt
#   inflating: RACE/RACE/train/high/19545.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._19545.txt
#   inflating: RACE/RACE/train/high/4331.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._4331.txt
#   inflating: RACE/RACE/train/high/2998.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._2998.txt
#   inflating: RACE/RACE/train/high/16676.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._16676.txt
#   inflating: RACE/RACE/train/high/11119.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._11119.txt
#   inflating: RACE/RACE/train/high/18883.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._18883.txt
#   inflating: RACE/RACE/train/high/5991.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._5991.txt
#   inflating: RACE/RACE/train/high/3338.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._3338.txt
#   inflating: RACE/RACE/train/high/16110.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._16110.txt
#   inflating: RACE/RACE/train/high/5749.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._5749.txt
#   inflating: RACE/RACE/train/high/10561.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._10561.txt
#   inflating: RACE/RACE/train/high/2026.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._2026.txt
#   inflating: RACE/RACE/train/high/13068.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._13068.txt
#   inflating: RACE/RACE/train/high/9173.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._9173.txt
#   inflating: RACE/RACE/train/high/14707.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._14707.txt
#   inflating: RACE/RACE/train/high/6240.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._6240.txt
#   inflating: RACE/RACE/train/high/15419.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._15419.txt
#   inflating: RACE/RACE/train/high/14713.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._14713.txt
#   inflating: RACE/RACE/train/high/9167.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._9167.txt
#   inflating: RACE/RACE/train/high/6254.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._6254.txt
#   inflating: RACE/RACE/train/high/8279.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._8279.txt
#   inflating: RACE/RACE/train/high/12362.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._12362.txt
#   inflating: RACE/RACE/train/high/5985.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._5985.txt
#   inflating: RACE/RACE/train/high/4443.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._4443.txt
#   inflating: RACE/RACE/train/high/19237.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._19237.txt
#   inflating: RACE/RACE/train/high/18129.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._18129.txt
#   inflating: RACE/RACE/train/high/21970.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._21970.txt
#   inflating: RACE/RACE/train/high/2032.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._2032.txt
#   inflating: RACE/RACE/train/high/10213.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._10213.txt
#   inflating: RACE/RACE/train/high/2754.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._2754.txt
#   inflating: RACE/RACE/train/high/4325.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._4325.txt
#   inflating: RACE/RACE/train/high/19551.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._19551.txt
#   inflating: RACE/RACE/train/high/18897.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._18897.txt
#   inflating: RACE/RACE/train/high/12404.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._12404.txt
#   inflating: RACE/RACE/train/high/911.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._911.txt
#   inflating: RACE/RACE/train/high/14075.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._14075.txt
#   inflating: RACE/RACE/train/high/9601.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._9601.txt
#   inflating: RACE/RACE/train/high/6532.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._6532.txt
#   inflating: RACE/RACE/train/high/16892.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._16892.txt
#   inflating: RACE/RACE/train/high/17554.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._17554.txt
#   inflating: RACE/RACE/train/high/18667.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._18667.txt
#   inflating: RACE/RACE/train/high/19579.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._19579.txt
#   inflating: RACE/RACE/train/high/11125.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._11125.txt
#   inflating: RACE/RACE/train/high/7604.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._7604.txt
#   inflating: RACE/RACE/train/high/13732.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._13732.txt
#   inflating: RACE/RACE/train/high/1275.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._1275.txt
#   inflating: RACE/RACE/train/high/13054.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._13054.txt
#   inflating: RACE/RACE/train/high/1513.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._1513.txt
#   inflating: RACE/RACE/train/high/23197.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._23197.txt
#   inflating: RACE/RACE/train/high/7162.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._7162.txt
#   inflating: RACE/RACE/train/high/8251.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._8251.txt
#   inflating: RACE/RACE/train/high/22289.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._22289.txt
#   inflating: RACE/RACE/train/high/21780.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._21780.txt
#   inflating: RACE/RACE/train/high/17232.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._17232.txt
#   inflating: RACE/RACE/train/high/5775.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._5775.txt
#   inflating: RACE/RACE/train/high/18101.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._18101.txt
#   inflating: RACE/RACE/train/high/11657.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._11657.txt
#   inflating: RACE/RACE/train/high/21794.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._21794.txt
#   inflating: RACE/RACE/train/high/18115.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._18115.txt
#   inflating: RACE/RACE/train/high/5761.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._5761.txt
#   inflating: RACE/RACE/train/high/10549.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._10549.txt
#   inflating: RACE/RACE/train/high/13040.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._13040.txt
#   inflating: RACE/RACE/train/high/23183.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._23183.txt
#   inflating: RACE/RACE/train/high/7176.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._7176.txt
#   inflating: RACE/RACE/train/high/8245.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._8245.txt
#   inflating: RACE/RACE/train/high/15431.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._15431.txt
#   inflating: RACE/RACE/train/high/7610.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._7610.txt
#   inflating: RACE/RACE/train/high/8523.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._8523.txt
#   inflating: RACE/RACE/train/high/15357.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._15357.txt
#   inflating: RACE/RACE/train/high/14049.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._14049.txt
#   inflating: RACE/RACE/train/high/13726.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._13726.txt
#   inflating: RACE/RACE/train/high/17540.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._17540.txt
#   inflating: RACE/RACE/train/high/18673.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._18673.txt
#   inflating: RACE/RACE/train/high/5007.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._5007.txt
#   inflating: RACE/RACE/train/high/4319.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._4319.txt
#   inflating: RACE/RACE/train/high/3476.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._3476.txt
#   inflating: RACE/RACE/train/high/11131.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._11131.txt
#   inflating: RACE/RACE/train/high/19586.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._19586.txt
#   inflating: RACE/RACE/train/high/21019.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._21019.txt
#   inflating: RACE/RACE/train/high/18840.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._18840.txt
#   inflating: RACE/RACE/train/high/2783.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._2783.txt
#   inflating: RACE/RACE/train/high/18698.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._18698.txt
#   inflating: RACE/RACE/train/high/20307.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._20307.txt
#   inflating: RACE/RACE/train/high/24161.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._24161.txt
#   inflating: RACE/RACE/train/high/7823.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._7823.txt
#   inflating: RACE/RACE/train/high/22510.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._22510.txt
#   inflating: RACE/RACE/train/high/13915.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._13915.txt
#   inflating: RACE/RACE/train/high/22276.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._22276.txt
#   inflating: RACE/RACE/train/high/23168.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._23168.txt
#   inflating: RACE/RACE/train/high/6283.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._6283.txt
#   inflating: RACE/RACE/train/high/11864.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._11864.txt
#   inflating: RACE/RACE/train/high/20461.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._20461.txt
#   inflating: RACE/RACE/train/high/5952.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._5952.txt
#   inflating: RACE/RACE/train/high/20475.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._20475.txt
#   inflating: RACE/RACE/train/high/5946.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._5946.txt
#   inflating: RACE/RACE/train/high/4480.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._4480.txt
#   inflating: RACE/RACE/train/high/7189.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._7189.txt
#   inflating: RACE/RACE/train/high/14908.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._14908.txt
#   inflating: RACE/RACE/train/high/6297.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._6297.txt
#   inflating: RACE/RACE/train/high/7837.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._7837.txt
#   inflating: RACE/RACE/train/high/24175.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._24175.txt
#   inflating: RACE/RACE/train/high/22504.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._22504.txt
#   inflating: RACE/RACE/train/high/13901.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._13901.txt
#   inflating: RACE/RACE/train/high/19592.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._19592.txt
#   inflating: RACE/RACE/train/high/18854.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._18854.txt
#   inflating: RACE/RACE/train/high/3489.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._3489.txt
#   inflating: RACE/RACE/train/high/2797.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._2797.txt
#   inflating: RACE/RACE/train/high/16879.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._16879.txt
#   inflating: RACE/RACE/train/high/20313.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._20313.txt
#   inflating: RACE/RACE/train/high/23632.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._23632.txt
#   inflating: RACE/RACE/train/high/722.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._722.txt
#   inflating: RACE/RACE/train/high/9832.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._9832.txt
#   inflating: RACE/RACE/train/high/13929.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._13929.txt
#   inflating: RACE/RACE/train/high/21025.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._21025.txt
#   inflating: RACE/RACE/train/high/16851.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._16851.txt
#   inflating: RACE/RACE/train/high/17597.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._17597.txt
#   inflating: RACE/RACE/train/high/11858.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._11858.txt
#   inflating: RACE/RACE/train/high/11680.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._11680.txt
#   inflating: RACE/RACE/train/high/21743.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._21743.txt
#   inflating: RACE/RACE/train/high/8292.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._8292.txt
#   inflating: RACE/RACE/train/high/12389.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._12389.txt
#   inflating: RACE/RACE/train/high/14920.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._14920.txt
#   inflating: RACE/RACE/train/high/13097.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._13097.txt
#   inflating: RACE/RACE/train/high/8286.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._8286.txt
#   inflating: RACE/RACE/train/high/14934.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._14934.txt
#   inflating: RACE/RACE/train/high/13083.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._13083.txt
#   inflating: RACE/RACE/train/high/23140.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._23140.txt
#   inflating: RACE/RACE/train/high/11694.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._11694.txt
#   inflating: RACE/RACE/train/high/21757.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._21757.txt
#   inflating: RACE/RACE/train/high/21031.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._21031.txt
#   inflating: RACE/RACE/train/high/2973.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._2973.txt
#   inflating: RACE/RACE/train/high/18868.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._18868.txt
#   inflating: RACE/RACE/train/high/16845.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._16845.txt
#   inflating: RACE/RACE/train/high/17583.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._17583.txt
#   inflating: RACE/RACE/train/high/23626.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._23626.txt
#   inflating: RACE/RACE/train/high/736.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._736.txt
#   inflating: RACE/RACE/train/high/9826.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._9826.txt
#   inflating: RACE/RACE/train/high/15394.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._15394.txt
#   inflating: RACE/RACE/train/high/22538.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._22538.txt
#   inflating: RACE/RACE/train/high/7994.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._7994.txt
#   inflating: RACE/RACE/train/high/9761.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._9761.txt
#   inflating: RACE/RACE/train/high/6452.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._6452.txt
#   inflating: RACE/RACE/train/high/871.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._871.txt
#   inflating: RACE/RACE/train/high/23961.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._23961.txt
#   inflating: RACE/RACE/train/high/12564.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._12564.txt
#   inflating: RACE/RACE/train/high/4245.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._4245.txt
#   inflating: RACE/RACE/train/high/19431.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._19431.txt
#   inflating: RACE/RACE/train/high/16702.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._16702.txt
#   inflating: RACE/RACE/train/high/10373.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._10373.txt
#   inflating: RACE/RACE/train/high/2634.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._2634.txt
#   inflating: RACE/RACE/train/high/10415.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._10415.txt
#   inflating: RACE/RACE/train/high/21810.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._21810.txt
#   inflating: RACE/RACE/train/high/2152.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._2152.txt
#   inflating: RACE/RACE/train/high/18049.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._18049.txt
#   inflating: RACE/RACE/train/high/4523.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._4523.txt
#   inflating: RACE/RACE/train/high/19357.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._19357.txt
#   inflating: RACE/RACE/train/high/16064.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._16064.txt
#   inflating: RACE/RACE/train/high/12202.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._12202.txt
#   inflating: RACE/RACE/train/high/14673.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._14673.txt
#   inflating: RACE/RACE/train/high/9007.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._9007.txt
#   inflating: RACE/RACE/train/high/6334.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._6334.txt
#   inflating: RACE/RACE/train/high/15579.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._15579.txt
#   inflating: RACE/RACE/train/high/9013.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._9013.txt
#   inflating: RACE/RACE/train/high/14667.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._14667.txt
#   inflating: RACE/RACE/train/high/6320.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._6320.txt
#   inflating: RACE/RACE/train/high/13108.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._13108.txt
#   inflating: RACE/RACE/train/high/10401.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._10401.txt
#   inflating: RACE/RACE/train/high/2146.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._2146.txt
#   inflating: RACE/RACE/train/high/21804.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._21804.txt
#   inflating: RACE/RACE/train/high/5629.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._5629.txt
#   inflating: RACE/RACE/train/high/19343.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._19343.txt
#   inflating: RACE/RACE/train/high/4537.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._4537.txt
#   inflating: RACE/RACE/train/high/16070.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._16070.txt
#   inflating: RACE/RACE/train/high/11079.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._11079.txt
#   inflating: RACE/RACE/train/high/19425.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._19425.txt
#   inflating: RACE/RACE/train/high/4251.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._4251.txt
#   inflating: RACE/RACE/train/high/16716.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._16716.txt
#   inflating: RACE/RACE/train/high/17408.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._17408.txt
#   inflating: RACE/RACE/train/high/10367.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._10367.txt
#   inflating: RACE/RACE/train/high/2620.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._2620.txt
#   inflating: RACE/RACE/train/high/7980.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._7980.txt
#   inflating: RACE/RACE/train/high/9775.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._9775.txt
#   inflating: RACE/RACE/train/high/14101.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._14101.txt
#   inflating: RACE/RACE/train/high/6446.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._6446.txt
#   inflating: RACE/RACE/train/high/25.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._25.txt
#   inflating: RACE/RACE/train/high/865.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._865.txt
#   inflating: RACE/RACE/train/high/7758.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._7758.txt
#   inflating: RACE/RACE/train/high/23975.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._23975.txt
#   inflating: RACE/RACE/train/high/12570.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._12570.txt
#   inflating: RACE/RACE/train/high/3516.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._3516.txt
#   inflating: RACE/RACE/train/high/21192.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._21192.txt
#   inflating: RACE/RACE/train/high/4279.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._4279.txt
#   inflating: RACE/RACE/train/high/18713.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._18713.txt
#   inflating: RACE/RACE/train/high/2608.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._2608.txt
#   inflating: RACE/RACE/train/high/13646.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._13646.txt
#   inflating: RACE/RACE/train/high/695.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._695.txt
#   inflating: RACE/RACE/train/high/14129.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._14129.txt
#   inflating: RACE/RACE/train/high/23785.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._23785.txt
#   inflating: RACE/RACE/train/high/8443.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._8443.txt
#   inflating: RACE/RACE/train/high/12558.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._12558.txt
#   inflating: RACE/RACE/train/high/7016.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._7016.txt
#   inflating: RACE/RACE/train/high/8325.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._8325.txt
#   inflating: RACE/RACE/train/high/15551.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._15551.txt
#   inflating: RACE/RACE/train/high/6308.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._6308.txt
#   inflating: RACE/RACE/train/high/13120.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._13120.txt
#   inflating: RACE/RACE/train/high/1467.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._1467.txt
#   inflating: RACE/RACE/train/high/17346.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._17346.txt
#   inflating: RACE/RACE/train/high/18075.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._18075.txt
#   inflating: RACE/RACE/train/high/5601.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._5601.txt
#   inflating: RACE/RACE/train/high/16058.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._16058.txt
#   inflating: RACE/RACE/train/high/3270.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._3270.txt
#   inflating: RACE/RACE/train/high/11737.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._11737.txt
#   inflating: RACE/RACE/train/high/17352.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._17352.txt
#   inflating: RACE/RACE/train/high/5615.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._5615.txt
#   inflating: RACE/RACE/train/high/18061.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._18061.txt
#   inflating: RACE/RACE/train/high/3264.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._3264.txt
#   inflating: RACE/RACE/train/high/11723.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._11723.txt
#   inflating: RACE/RACE/train/high/14883.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._14883.txt
#   inflating: RACE/RACE/train/high/7002.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._7002.txt
#   inflating: RACE/RACE/train/high/15545.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._15545.txt
#   inflating: RACE/RACE/train/high/8331.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._8331.txt
#   inflating: RACE/RACE/train/high/13134.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._13134.txt
#   inflating: RACE/RACE/train/high/13652.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._13652.txt
#   inflating: RACE/RACE/train/high/1315.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._1315.txt
#   inflating: RACE/RACE/train/high/681.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._681.txt
#   inflating: RACE/RACE/train/high/23791.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._23791.txt
#   inflating: RACE/RACE/train/high/9749.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._9749.txt
#   inflating: RACE/RACE/train/high/7764.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._7764.txt
#   inflating: RACE/RACE/train/high/15223.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._15223.txt
#   inflating: RACE/RACE/train/high/8457.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._8457.txt
#   inflating: RACE/RACE/train/high/859.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._859.txt
#   inflating: RACE/RACE/train/high/23949.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._23949.txt
#   inflating: RACE/RACE/train/high/9991.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._9991.txt
#   inflating: RACE/RACE/train/high/3502.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._3502.txt
#   inflating: RACE/RACE/train/high/11045.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._11045.txt
#   inflating: RACE/RACE/train/high/19419.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._19419.txt
#   inflating: RACE/RACE/train/high/17434.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._17434.txt
#   inflating: RACE/RACE/train/high/20298.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._20298.txt
#   inflating: RACE/RACE/train/high/5173.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._5173.txt
#   inflating: RACE/RACE/train/high/18707.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._18707.txt
#   inflating: RACE/RACE/train/high/20273.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._20273.txt
#   inflating: RACE/RACE/train/high/16919.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._16919.txt
#   inflating: RACE/RACE/train/high/18934.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._18934.txt
#   inflating: RACE/RACE/train/high/4286.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._4286.txt
#   inflating: RACE/RACE/train/high/13861.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._13861.txt
#   inflating: RACE/RACE/train/high/7957.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._7957.txt
#   inflating: RACE/RACE/train/high/1498.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._1498.txt
#   inflating: RACE/RACE/train/high/14868.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._14868.txt
#   inflating: RACE/RACE/train/high/22302.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._22302.txt
#   inflating: RACE/RACE/train/high/19394.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._19394.txt
#   inflating: RACE/RACE/train/high/5826.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._5826.txt
#   inflating: RACE/RACE/train/high/11910.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._11910.txt
#   inflating: RACE/RACE/train/high/19380.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._19380.txt
#   inflating: RACE/RACE/train/high/5832.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._5832.txt
#   inflating: RACE/RACE/train/high/2185.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._2185.txt
#   inflating: RACE/RACE/train/high/20501.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._20501.txt
#   inflating: RACE/RACE/train/high/23008.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._23008.txt
#   inflating: RACE/RACE/train/high/118.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._118.txt
#   inflating: RACE/RACE/train/high/22316.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._22316.txt
#   inflating: RACE/RACE/train/high/13875.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._13875.txt
#   inflating: RACE/RACE/train/high/24001.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._24001.txt
#   inflating: RACE/RACE/train/high/7943.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._7943.txt
#   inflating: RACE/RACE/train/high/18920.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._18920.txt
#   inflating: RACE/RACE/train/high/4292.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._4292.txt
#   inflating: RACE/RACE/train/high/21179.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._21179.txt
#   inflating: RACE/RACE/train/high/8480.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._8480.txt
#   inflating: RACE/RACE/train/high/22458.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._22458.txt
#   inflating: RACE/RACE/train/high/9946.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._9946.txt
#   inflating: RACE/RACE/train/high/656.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._656.txt
#   inflating: RACE/RACE/train/high/23746.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._23746.txt
#   inflating: RACE/RACE/train/high/16925.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._16925.txt
#   inflating: RACE/RACE/train/high/18908.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._18908.txt
#   inflating: RACE/RACE/train/high/21151.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._21151.txt
#   inflating: RACE/RACE/train/high/2813.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._2813.txt
#   inflating: RACE/RACE/train/high/17385.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._17385.txt
#   inflating: RACE/RACE/train/high/23020.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._23020.txt
#   inflating: RACE/RACE/train/high/130.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._130.txt
#   inflating: RACE/RACE/train/high/14854.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._14854.txt
#   inflating: RACE/RACE/train/high/14698.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._14698.txt
#   inflating: RACE/RACE/train/high/23034.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._23034.txt
#   inflating: RACE/RACE/train/high/124.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._124.txt
#   inflating: RACE/RACE/train/high/21623.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._21623.txt
#   inflating: RACE/RACE/train/high/17391.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._17391.txt
#   inflating: RACE/RACE/train/high/16931.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._16931.txt
#   inflating: RACE/RACE/train/high/10398.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._10398.txt
#   inflating: RACE/RACE/train/high/11086.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._11086.txt
#   inflating: RACE/RACE/train/high/2807.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._2807.txt
#   inflating: RACE/RACE/train/high/21145.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._21145.txt
#   inflating: RACE/RACE/train/high/13849.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._13849.txt
#   inflating: RACE/RACE/train/high/8494.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._8494.txt
#   inflating: RACE/RACE/train/high/9952.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._9952.txt
#   inflating: RACE/RACE/train/high/13691.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._13691.txt
#   inflating: RACE/RACE/train/high/642.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._642.txt
#   inflating: RACE/RACE/train/high/23752.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._23752.txt
#   inflating: RACE/RACE/train/high/1659.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._1659.txt
#   inflating: RACE/RACE/train/high/6136.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._6136.txt
#   inflating: RACE/RACE/train/high/14471.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._14471.txt
#   inflating: RACE/RACE/train/high/7228.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._7228.txt
#   inflating: RACE/RACE/train/high/1881.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._1881.txt
#   inflating: RACE/RACE/train/high/12000.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._12000.txt
#   inflating: RACE/RACE/train/high/16266.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._16266.txt
#   inflating: RACE/RACE/train/high/4721.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._4721.txt
#   inflating: RACE/RACE/train/high/17178.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._17178.txt
#   inflating: RACE/RACE/train/high/2350.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._2350.txt
#   inflating: RACE/RACE/train/high/10171.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._10171.txt
#   inflating: RACE/RACE/train/high/5359.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._5359.txt
#   inflating: RACE/RACE/train/high/4047.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._4047.txt
#   inflating: RACE/RACE/train/high/3728.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._3728.txt
#   inflating: RACE/RACE/train/high/6888.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._6888.txt
#   inflating: RACE/RACE/train/high/12766.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._12766.txt
#   inflating: RACE/RACE/train/high/15009.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._15009.txt
#   inflating: RACE/RACE/train/high/6650.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._6650.txt
#   inflating: RACE/RACE/train/high/14317.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._14317.txt
#   inflating: RACE/RACE/train/high/9563.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._9563.txt
#   inflating: RACE/RACE/train/high/13478.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._13478.txt
#   inflating: RACE/RACE/train/high/12772.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._12772.txt
#   inflating: RACE/RACE/train/high/8669.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._8669.txt
#   inflating: RACE/RACE/train/high/6644.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._6644.txt
#   inflating: RACE/RACE/train/high/9577.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._9577.txt
#   inflating: RACE/RACE/train/high/22869.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._22869.txt
#   inflating: RACE/RACE/train/high/10165.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._10165.txt
#   inflating: RACE/RACE/train/high/18539.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._18539.txt
#   inflating: RACE/RACE/train/high/19627.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._19627.txt
#   inflating: RACE/RACE/train/high/4053.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._4053.txt
#   inflating: RACE/RACE/train/high/16272.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._16272.txt
#   inflating: RACE/RACE/train/high/19141.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._19141.txt
#   inflating: RACE/RACE/train/high/4735.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._4735.txt
#   inflating: RACE/RACE/train/high/2344.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._2344.txt
#   inflating: RACE/RACE/train/high/10603.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._10603.txt
#   inflating: RACE/RACE/train/high/6122.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._6122.txt
#   inflating: RACE/RACE/train/high/9211.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._9211.txt
#   inflating: RACE/RACE/train/high/14465.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._14465.txt
#   inflating: RACE/RACE/train/high/12014.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._12014.txt
#   inflating: RACE/RACE/train/high/11535.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._11535.txt
#   inflating: RACE/RACE/train/high/20930.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._20930.txt
#   inflating: RACE/RACE/train/high/3072.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._3072.txt
#   inflating: RACE/RACE/train/high/19169.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._19169.txt
#   inflating: RACE/RACE/train/high/18277.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._18277.txt
#   inflating: RACE/RACE/train/high/5403.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._5403.txt
#   inflating: RACE/RACE/train/high/17144.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._17144.txt
#   inflating: RACE/RACE/train/high/1665.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._1665.txt
#   inflating: RACE/RACE/train/high/13322.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._13322.txt
#   inflating: RACE/RACE/train/high/9239.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._9239.txt
#   inflating: RACE/RACE/train/high/8127.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._8127.txt
#   inflating: RACE/RACE/train/high/15753.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._15753.txt
#   inflating: RACE/RACE/train/high/7214.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._7214.txt
#   inflating: RACE/RACE/train/high/8641.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._8641.txt
#   inflating: RACE/RACE/train/high/15035.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._15035.txt
#   inflating: RACE/RACE/train/high/22699.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._22699.txt
#   inflating: RACE/RACE/train/high/12982.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._12982.txt
#   inflating: RACE/RACE/train/high/8899.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._8899.txt
#   inflating: RACE/RACE/train/high/1103.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._1103.txt
#   inflating: RACE/RACE/train/high/22841.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._22841.txt
#   inflating: RACE/RACE/train/high/497.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._497.txt
#   inflating: RACE/RACE/train/high/13444.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._13444.txt
#   inflating: RACE/RACE/train/high/18511.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._18511.txt
#   inflating: RACE/RACE/train/high/17622.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._17622.txt
#   inflating: RACE/RACE/train/high/21390.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._21390.txt
#   inflating: RACE/RACE/train/high/11253.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._11253.txt
#   inflating: RACE/RACE/train/high/3714.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._3714.txt
#   inflating: RACE/RACE/train/high/10159.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._10159.txt
#   inflating: RACE/RACE/train/high/5371.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._5371.txt
#   inflating: RACE/RACE/train/high/18505.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._18505.txt
#   inflating: RACE/RACE/train/high/17636.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._17636.txt
#   inflating: RACE/RACE/train/high/16528.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._16528.txt
#   inflating: RACE/RACE/train/high/21384.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._21384.txt
#   inflating: RACE/RACE/train/high/11247.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._11247.txt
#   inflating: RACE/RACE/train/high/3700.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._3700.txt
#   inflating: RACE/RACE/train/high/15021.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._15021.txt
#   inflating: RACE/RACE/train/high/8655.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._8655.txt
#   inflating: RACE/RACE/train/high/7566.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._7566.txt
#   inflating: RACE/RACE/train/high/23593.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._23593.txt
#   inflating: RACE/RACE/train/high/12996.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._12996.txt
#   inflating: RACE/RACE/train/high/483.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._483.txt
#   inflating: RACE/RACE/train/high/22855.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._22855.txt
#   inflating: RACE/RACE/train/high/1117.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._1117.txt
#   inflating: RACE/RACE/train/high/13450.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._13450.txt
#   inflating: RACE/RACE/train/high/1671.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._1671.txt
#   inflating: RACE/RACE/train/high/13336.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._13336.txt
#   inflating: RACE/RACE/train/high/14459.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._14459.txt
#   inflating: RACE/RACE/train/high/15747.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._15747.txt
#   inflating: RACE/RACE/train/high/7200.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._7200.txt
#   inflating: RACE/RACE/train/high/3066.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._3066.txt
#   inflating: RACE/RACE/train/high/4709.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._4709.txt
#   inflating: RACE/RACE/train/high/5417.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._5417.txt
#   inflating: RACE/RACE/train/high/18263.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._18263.txt
#   inflating: RACE/RACE/train/high/17150.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._17150.txt
#   inflating: RACE/RACE/train/high/20717.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._20717.txt
#   inflating: RACE/RACE/train/high/2393.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._2393.txt
#   inflating: RACE/RACE/train/high/21409.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._21409.txt
#   inflating: RACE/RACE/train/high/19196.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._19196.txt
#   inflating: RACE/RACE/train/high/1842.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._1842.txt
#   inflating: RACE/RACE/train/high/22100.txt
#   inflating: __MACOSX/RACE/RACE/train/high/._22100.txt
#   inflating: RACE/RACE/train/high/15974.txt
# ...
#   inflating: __MACOSX/RACE/RACE/dev/high/._7574.txt
#   inflating: RACE/RACE/dev/high/10177.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._10177.txt
#   inflating: RACE/RACE/dev/high/309.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._309.txt
#   inflating: RACE/RACE/dev/high/5389.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._5389.txt
#   inflating: RACE/RACE/dev/high/4915.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._4915.txt
#   inflating: RACE/RACE/dev/high/3049.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._3049.txt
#   inflating: RACE/RACE/dev/high/13319.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._13319.txt
#   inflating: RACE/RACE/dev/high/17619.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._17619.txt
#   inflating: RACE/RACE/dev/high/11532.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._11532.txt
#   inflating: RACE/RACE/dev/high/22463.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._22463.txt
#   inflating: RACE/RACE/dev/high/4281.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._4281.txt
#   inflating: RACE/RACE/dev/high/22311.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._22311.txt
#   inflating: RACE/RACE/dev/high/7944.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._7944.txt
#   inflating: RACE/RACE/dev/high/21142.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._21142.txt
#   inflating: RACE/RACE/dev/high/2800.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._2800.txt
#   inflating: RACE/RACE/dev/high/19344.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._19344.txt
#   inflating: RACE/RACE/dev/high/15224.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._15224.txt
#   inflating: RACE/RACE/dev/high/23609.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._23609.txt
#   inflating: RACE/RACE/dev/high/18847.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._18847.txt
#   inflating: RACE/RACE/dev/high/5941.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._5941.txt
#   inflating: RACE/RACE/dev/high/24172.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._24172.txt
#   inflating: RACE/RACE/dev/high/14933.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._14933.txt
#   inflating: RACE/RACE/dev/high/18890.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._18890.txt
#   inflating: RACE/RACE/dev/high/1272.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._1272.txt
#   inflating: RACE/RACE/dev/high/18660.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._18660.txt
#   inflating: RACE/RACE/dev/high/19218.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._19218.txt
#   inflating: RACE/RACE/dev/high/1500.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._1500.txt
#   inflating: RACE/RACE/dev/high/3471.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._3471.txt
#   inflating: RACE/RACE/dev/high/17547.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._17547.txt
#   inflating: RACE/RACE/dev/high/18674.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._18674.txt
#   inflating: RACE/RACE/dev/high/1266.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._1266.txt
#   inflating: RACE/RACE/dev/high/22067.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._22067.txt
#   inflating: RACE/RACE/dev/high/12832.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._12832.txt
#   inflating: RACE/RACE/dev/high/16467.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._16467.txt
#   inflating: RACE/RACE/dev/high/13279.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._13279.txt
#   inflating: RACE/RACE/dev/high/15608.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._15608.txt
#   inflating: RACE/RACE/dev/high/19032.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._19032.txt
#   inflating: RACE/RACE/dev/high/4646.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._4646.txt
#   inflating: RACE/RACE/dev/high/13251.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._13251.txt
#   inflating: RACE/RACE/dev/high/5202.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._5202.txt
#   inflating: RACE/RACE/dev/high/1048.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._1048.txt
#   inflating: RACE/RACE/dev/high/10760.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._10760.txt
#   inflating: RACE/RACE/dev/high/4656.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._4656.txt
#   inflating: RACE/RACE/dev/high/8736.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._8736.txt
#   inflating: RACE/RACE/dev/high/19778.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._19778.txt
#   inflating: RACE/RACE/dev/high/17755.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._17755.txt
#   inflating: RACE/RACE/dev/high/5574.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._5574.txt
#   inflating: RACE/RACE/dev/high/7363.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._7363.txt
#   inflating: RACE/RACE/dev/high/22077.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._22077.txt
#   inflating: RACE/RACE/dev/high/9399.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._9399.txt
#   inflating: RACE/RACE/dev/high/18894.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._18894.txt
#   inflating: RACE/RACE/dev/high/8508.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._8508.txt
#   inflating: RACE/RACE/dev/high/9616.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._9616.txt
#   inflating: RACE/RACE/dev/high/5004.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._5004.txt
#   inflating: RACE/RACE/dev/high/11654.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._11654.txt
#   inflating: RACE/RACE/dev/high/13043.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._13043.txt
#   inflating: RACE/RACE/dev/high/15432.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._15432.txt
#   inflating: RACE/RACE/dev/high/23619.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._23619.txt
#   inflating: RACE/RACE/dev/high/23625.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._23625.txt
#   inflating: RACE/RACE/dev/high/721.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._721.txt
#   inflating: RACE/RACE/dev/high/16715.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._16715.txt
#   inflating: RACE/RACE/dev/high/4520.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._4520.txt
#   inflating: RACE/RACE/dev/high/15208.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._15208.txt
#   inflating: RACE/RACE/dev/high/2186.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._2186.txt
#   inflating: RACE/RACE/dev/high/20516.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._20516.txt
#   inflating: RACE/RACE/dev/high/9979.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._9979.txt
#   inflating: RACE/RACE/dev/high/21620.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._21620.txt
#   inflating: RACE/RACE/dev/high/12771.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._12771.txt
#   inflating: RACE/RACE/dev/high/4050.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._4050.txt
#   inflating: RACE/RACE/dev/high/5400.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._5400.txt
#   inflating: RACE/RACE/dev/high/2390.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._2390.txt
#   inflating: RACE/RACE/dev/high/19195.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._19195.txt
#   inflating: RACE/RACE/dev/high/318.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._318.txt
#   inflating: RACE/RACE/dev/high/12016.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._12016.txt
#   inflating: RACE/RACE/dev/high/11279.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._11279.txt
#   inflating: RACE/RACE/dev/high/8482.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._8482.txt
#   inflating: RACE/RACE/dev/high/9987.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._9987.txt
#   inflating: RACE/RACE/dev/high/23787.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._23787.txt
#   inflating: RACE/RACE/dev/high/18711.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._18711.txt
#   inflating: RACE/RACE/dev/high/16728.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._16728.txt
#   inflating: RACE/RACE/dev/high/14659.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._14659.txt
#   inflating: RACE/RACE/dev/high/13095.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._13095.txt
#   inflating: RACE/RACE/dev/high/16853.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._16853.txt
#   inflating: RACE/RACE/dev/high/21769.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._21769.txt
#   inflating: RACE/RACE/dev/high/21782.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._21782.txt
#   inflating: RACE/RACE/dev/high/18665.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._18665.txt
#   inflating: RACE/RACE/dev/high/20488.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._20488.txt
#   inflating: RACE/RACE/dev/high/19235.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._19235.txt
#   inflating: RACE/RACE/dev/high/23432.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._23432.txt
#   inflating: RACE/RACE/dev/high/3879.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._3879.txt
#   inflating: RACE/RACE/dev/high/10946.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._10946.txt
#   inflating: RACE/RACE/dev/high/23340.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._23340.txt
#   inflating: RACE/RACE/dev/high/23426.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._23426.txt
#   inflating: RACE/RACE/dev/high/6915.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._6915.txt
#   inflating: RACE/RACE/dev/high/15194.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._15194.txt
#   inflating: RACE/RACE/dev/high/20675.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._20675.txt
#   inflating: RACE/RACE/dev/high/22062.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._22062.txt
#   inflating: RACE/RACE/dev/high/15625.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._15625.txt
#   inflating: RACE/RACE/dev/high/23383.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._23383.txt
#   inflating: RACE/RACE/dev/high/4657.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._4657.txt
#   inflating: RACE/RACE/dev/high/10775.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._10775.txt
#   inflating: RACE/RACE/dev/high/19751.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._19751.txt
#   inflating: RACE/RACE/dev/high/9417.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._9417.txt
#   inflating: RACE/RACE/dev/high/11327.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._11327.txt
#   inflating: RACE/RACE/dev/high/18465.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._18465.txt
#   inflating: RACE/RACE/dev/high/23356.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._23356.txt
#   inflating: RACE/RACE/dev/high/10944.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._10944.txt
#   inflating: RACE/RACE/dev/high/15182.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._15182.txt
#   inflating: RACE/RACE/dev/high/6903.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._6903.txt
#   inflating: RACE/RACE/dev/high/10788.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._10788.txt
#   inflating: RACE/RACE/dev/high/17568.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._17568.txt
#   inflating: RACE/RACE/dev/high/23801.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._23801.txt
#   inflating: RACE/RACE/dev/high/3462.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._3462.txt
#   inflating: RACE/RACE/dev/high/939.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._939.txt
#   inflating: RACE/RACE/dev/high/21958.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._21958.txt
#   inflating: RACE/RACE/dev/high/16138.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._16138.txt
#   inflating: RACE/RACE/dev/high/22262.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._22262.txt
#   inflating: RACE/RACE/dev/high/20449.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._20449.txt
#   inflating: RACE/RACE/dev/high/10429.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._10429.txt
#   inflating: RACE/RACE/dev/high/21838.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._21838.txt
#   inflating: RACE/RACE/dev/high/5198.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._5198.txt
#   inflating: RACE/RACE/dev/high/11904.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._11904.txt
#   inflating: RACE/RACE/dev/high/22470.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._22470.txt
#   inflating: RACE/RACE/dev/high/15586.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._15586.txt
#   inflating: RACE/RACE/dev/high/11938.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._11938.txt
#   inflating: RACE/RACE/dev/high/11509.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._11509.txt
#   inflating: RACE/RACE/dev/high/11521.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._11521.txt
#   inflating: RACE/RACE/dev/high/2378.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._2378.txt
#   inflating: RACE/RACE/dev/high/18288.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._18288.txt
#   inflating: RACE/RACE/dev/high/22666.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._22666.txt
#   inflating: RACE/RACE/dev/high/17805.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._17805.txt
#   inflating: RACE/RACE/dev/high/19814.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._19814.txt
#   inflating: RACE/RACE/dev/high/12941.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._12941.txt
#   inflating: RACE/RACE/dev/high/17193.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._17193.txt
#   inflating: RACE/RACE/dev/high/17810.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._17810.txt
#   inflating: RACE/RACE/dev/high/19183.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._19183.txt
#   inflating: RACE/RACE/dev/high/18262.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._18262.txt
#   inflating: RACE/RACE/dev/high/8132.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._8132.txt
#   inflating: RACE/RACE/dev/high/5402.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._5402.txt
#   inflating: RACE/RACE/dev/high/11252.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._11252.txt
#   inflating: RACE/RACE/dev/high/2423.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._2423.txt
#   inflating: RACE/RACE/dev/high/2351.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._2351.txt
#   inflating: RACE/RACE/dev/high/14841.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._14841.txt
#   inflating: RACE/RACE/dev/high/657.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._657.txt
#   inflating: RACE/RACE/dev/high/14855.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._14855.txt
#   inflating: RACE/RACE/dev/high/15544.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._15544.txt
#   inflating: RACE/RACE/dev/high/18060.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._18060.txt
#   inflating: RACE/RACE/dev/high/6447.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._6447.txt
#   inflating: RACE/RACE/dev/high/19424.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._19424.txt
#   inflating: RACE/RACE/dev/high/2966.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._2966.txt
#   inflating: RACE/RACE/dev/high/7822.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._7822.txt
#   inflating: RACE/RACE/dev/high/18699.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._18699.txt
#   inflating: RACE/RACE/dev/high/23828.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._23828.txt
#   inflating: RACE/RACE/dev/high/23196.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._23196.txt
#   inflating: RACE/RACE/dev/high/19544.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._19544.txt
#   inflating: RACE/RACE/dev/high/6527.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._6527.txt
#   inflating: RACE/RACE/dev/high/7639.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._7639.txt
#   inflating: RACE/RACE/dev/high/15418.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._15418.txt
#   inflating: RACE/RACE/dev/high/21540.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._21540.txt
#   inflating: RACE/RACE/dev/high/247.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._247.txt
#   inflating: RACE/RACE/dev/high/5562.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._5562.txt
#   inflating: RACE/RACE/dev/high/8046.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._8046.txt
#   inflating: RACE/RACE/dev/high/8708.txt
#   inflating: __MACOSX/RACE/RACE/dev/high/._8708.txt

# %%
! git clone https://github.com/NVIDIA/apex.git
% cd apex
! pip install -v --no-cache-dir ./
# %cd ..

from apex import amp

import pandas as pd
import numpy as np
import logging
import argparse
import random
import numpy as np
import os
import time
import glob
import json

import nltk
nltk.download('punkt')
from nltk.tokenize import sent_tokenize

# !pip install transformers
# !pip install sentencepiece
from transformers import DistilBertConfig, DistilBertTokenizer, DistilBertForMultipleChoice
from transformers import AdamW, get_linear_schedule_with_warmup, AlbertConfig, AlbertTokenizer, AlbertForMultipleChoice

import torch
from torch.optim.adam import Adam
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
from torch.utils.data.distributed import DistributedSampler
from torch.nn.utils.rnn import pad_sequence
# Out:
# Cloning into 'apex'...
# remote: Enumerating objects: 26, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 7939 (delta 5), reused 12 (delta 0), pack-reused 7913
# Receiving objects: 100% (7939/7939), 14.03 MiB | 27.30 MiB/s, done.
# Resolving deltas: 100% (5404/5404), done.
# /content/apex
# Created temporary directory: /tmp/pip-ephem-wheel-cache-xd_ed1xp
# Created temporary directory: /tmp/pip-req-tracker-7u4k5omj
# Created requirements tracker '/tmp/pip-req-tracker-7u4k5omj'
# Created temporary directory: /tmp/pip-install-bhaa4ud5
# Processing /content/apex
#   Created temporary directory: /tmp/pip-req-build-kksoyrx5
#   Added file:///content/apex to build tracker '/tmp/pip-req-tracker-7u4k5omj'
#     Running setup.py (path:/tmp/pip-req-build-kksoyrx5/setup.py) egg_info for package from file:///content/apex
#     Running command python setup.py egg_info
#
#
#     torch.__version__  = 1.8.1+cu101
#
#
#     running egg_info
#     creating /tmp/pip-req-build-kksoyrx5/pip-egg-info/apex.egg-info
#     writing /tmp/pip-req-build-kksoyrx5/pip-egg-info/apex.egg-info/PKG-INFO
#     writing dependency_links to /tmp/pip-req-build-kksoyrx5/pip-egg-info/apex.egg-info/dependency_links.txt
#     writing top-level names to /tmp/pip-req-build-kksoyrx5/pip-egg-info/apex.egg-info/top_level.txt
#     writing manifest file '/tmp/pip-req-build-kksoyrx5/pip-egg-info/apex.egg-info/SOURCES.txt'
#     writing manifest file '/tmp/pip-req-build-kksoyrx5/pip-egg-info/apex.egg-info/SOURCES.txt'
#     /tmp/pip-req-build-kksoyrx5/setup.py:67: UserWarning: Option --pyprof not specified. Not installing PyProf dependencies!
#       warnings.warn("Option --pyprof not specified. Not installing PyProf dependencies!")
#   Source in /tmp/pip-req-build-kksoyrx5 has version 0.1, which satisfies requirement apex==0.1 from file:///content/apex
#   Removed apex==0.1 from file:///content/apex from build tracker '/tmp/pip-req-tracker-7u4k5omj'
# Building wheels for collected packages: apex
#   Created temporary directory: /tmp/pip-wheel-mkxke5vv
#   Building wheel for apex (setup.py) ...   Destination directory: /tmp/pip-wheel-mkxke5vv
#   Running command /usr/bin/python3 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-req-build-kksoyrx5/setup.py'"'"'; __file__='"'"'/tmp/pip-req-build-kksoyrx5/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-mkxke5vv --python-tag cp37
#
#
#   torch.__version__  = 1.8.1+cu101
#
#
#   /tmp/pip-req-build-kksoyrx5/setup.py:67: UserWarning: Option --pyprof not specified. Not installing PyProf dependencies!
#     warnings.warn("Option --pyprof not specified. Not installing PyProf dependencies!")
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib
#   creating build/lib/apex
#   copying apex/__init__.py -> build/lib/apex
#   creating build/lib/apex/RNN
#   copying apex/RNN/__init__.py -> build/lib/apex/RNN
#   copying apex/RNN/cells.py -> build/lib/apex/RNN
#   copying apex/RNN/models.py -> build/lib/apex/RNN
#   copying apex/RNN/RNNBackend.py -> build/lib/apex/RNN
#   creating build/lib/apex/normalization
#   copying apex/normalization/__init__.py -> build/lib/apex/normalization
#   copying apex/normalization/fused_layer_norm.py -> build/lib/apex/normalization
#   creating build/lib/apex/mlp
#   copying apex/mlp/__init__.py -> build/lib/apex/mlp
#   copying apex/mlp/mlp.py -> build/lib/apex/mlp
#   creating build/lib/apex/contrib
#   copying apex/contrib/__init__.py -> build/lib/apex/contrib
#   creating build/lib/apex/amp
#   copying apex/amp/_initialize.py -> build/lib/apex/amp
#   copying apex/amp/amp.py -> build/lib/apex/amp
#   copying apex/amp/opt.py -> build/lib/apex/amp
#   copying apex/amp/__init__.py -> build/lib/apex/amp
#   copying apex/amp/_amp_state.py -> build/lib/apex/amp
#   copying apex/amp/_process_optimizer.py -> build/lib/apex/amp
#   copying apex/amp/compat.py -> build/lib/apex/amp
#   copying apex/amp/utils.py -> build/lib/apex/amp
#   copying apex/amp/__version__.py -> build/lib/apex/amp
#   copying apex/amp/wrap.py -> build/lib/apex/amp
#   copying apex/amp/handle.py -> build/lib/apex/amp
#   copying apex/amp/rnn_compat.py -> build/lib/apex/amp
#   copying apex/amp/scaler.py -> build/lib/apex/amp
#   copying apex/amp/frontend.py -> build/lib/apex/amp
#   creating build/lib/apex/optimizers
#   copying apex/optimizers/fused_lamb.py -> build/lib/apex/optimizers
#   copying apex/optimizers/fused_sgd.py -> build/lib/apex/optimizers
#   copying apex/optimizers/fused_novograd.py -> build/lib/apex/optimizers
#   copying apex/optimizers/__init__.py -> build/lib/apex/optimizers
#   copying apex/optimizers/fused_adagrad.py -> build/lib/apex/optimizers
#   copying apex/optimizers/fused_adam.py -> build/lib/apex/optimizers
#   creating build/lib/apex/pyprof
#   copying apex/pyprof/__init__.py -> build/lib/apex/pyprof
#   creating build/lib/apex/parallel
#   copying apex/parallel/sync_batchnorm.py -> build/lib/apex/parallel
#   copying apex/parallel/optimized_sync_batchnorm.py -> build/lib/apex/parallel
#   copying apex/parallel/LARC.py -> build/lib/apex/parallel
#   copying apex/parallel/sync_batchnorm_kernel.py -> build/lib/apex/parallel
#   copying apex/parallel/multiproc.py -> build/lib/apex/parallel
#   copying apex/parallel/__init__.py -> build/lib/apex/parallel
#   copying apex/parallel/optimized_sync_batchnorm_kernel.py -> build/lib/apex/parallel
#   copying apex/parallel/distributed.py -> build/lib/apex/parallel
#   creating build/lib/apex/multi_tensor_apply
#   copying apex/multi_tensor_apply/__init__.py -> build/lib/apex/multi_tensor_apply
#   copying apex/multi_tensor_apply/multi_tensor_apply.py -> build/lib/apex/multi_tensor_apply
#   creating build/lib/apex/reparameterization
#   copying apex/reparameterization/reparameterization.py -> build/lib/apex/reparameterization
#   copying apex/reparameterization/__init__.py -> build/lib/apex/reparameterization
#   copying apex/reparameterization/weight_norm.py -> build/lib/apex/reparameterization
#   creating build/lib/apex/fp16_utils
#   copying apex/fp16_utils/loss_scaler.py -> build/lib/apex/fp16_utils
#   copying apex/fp16_utils/__init__.py -> build/lib/apex/fp16_utils
#   copying apex/fp16_utils/fp16_optimizer.py -> build/lib/apex/fp16_utils
#   copying apex/fp16_utils/fp16util.py -> build/lib/apex/fp16_utils
#   creating build/lib/apex/contrib/multihead_attn
#   copying apex/contrib/multihead_attn/fast_self_multihead_attn_func.py -> build/lib/apex/contrib/multihead_attn
#   copying apex/contrib/multihead_attn/fast_self_multihead_attn_norm_add_func.py -> build/lib/apex/contrib/multihead_attn
#   copying apex/contrib/multihead_attn/__init__.py -> build/lib/apex/contrib/multihead_attn
#   copying apex/contrib/multihead_attn/self_multihead_attn_func.py -> build/lib/apex/contrib/multihead_attn
#   copying apex/contrib/multihead_attn/mask_softmax_dropout_func.py -> build/lib/apex/contrib/multihead_attn
#   copying apex/contrib/multihead_attn/encdec_multihead_attn_func.py -> build/lib/apex/contrib/multihead_attn
#   copying apex/contrib/multihead_attn/fast_encdec_multihead_attn_func.py -> build/lib/apex/contrib/multihead_attn
#   copying apex/contrib/multihead_attn/encdec_multihead_attn.py -> build/lib/apex/contrib/multihead_attn
#   copying apex/contrib/multihead_attn/self_multihead_attn.py -> build/lib/apex/contrib/multihead_attn
#   copying apex/contrib/multihead_attn/fast_encdec_multihead_attn_norm_add_func.py -> build/lib/apex/contrib/multihead_attn
#   creating build/lib/apex/contrib/sparsity
#   copying apex/contrib/sparsity/sparse_masklib.py -> build/lib/apex/contrib/sparsity
#   copying apex/contrib/sparsity/__init__.py -> build/lib/apex/contrib/sparsity
#   copying apex/contrib/sparsity/asp.py -> build/lib/apex/contrib/sparsity
#   creating build/lib/apex/contrib/optimizers
#   copying apex/contrib/optimizers/fused_lamb.py -> build/lib/apex/contrib/optimizers
#   copying apex/contrib/optimizers/fused_sgd.py -> build/lib/apex/contrib/optimizers
#   copying apex/contrib/optimizers/distributed_fused_lamb.py -> build/lib/apex/contrib/optimizers
#   copying apex/contrib/optimizers/__init__.py -> build/lib/apex/contrib/optimizers
#   copying apex/contrib/optimizers/fp16_optimizer.py -> build/lib/apex/contrib/optimizers
#   copying apex/contrib/optimizers/distributed_fused_adam_v2.py -> build/lib/apex/contrib/optimizers
#   copying apex/contrib/optimizers/fused_adam.py -> build/lib/apex/contrib/optimizers
#   copying apex/contrib/optimizers/distributed_fused_adam.py -> build/lib/apex/contrib/optimizers
#   copying apex/contrib/optimizers/distributed_fused_adam_v3.py -> build/lib/apex/contrib/optimizers
#   creating build/lib/apex/contrib/transducer
#   copying apex/contrib/transducer/__init__.py -> build/lib/apex/contrib/transducer
#   copying apex/contrib/transducer/transducer.py -> build/lib/apex/contrib/transducer
#   creating build/lib/apex/contrib/groupbn
#   copying apex/contrib/groupbn/batch_norm.py -> build/lib/apex/contrib/groupbn
#   copying apex/contrib/groupbn/__init__.py -> build/lib/apex/contrib/groupbn
#   creating build/lib/apex/contrib/xentropy
#   copying apex/contrib/xentropy/__init__.py -> build/lib/apex/contrib/xentropy
#   copying apex/contrib/xentropy/softmax_xentropy.py -> build/lib/apex/contrib/xentropy
#   creating build/lib/apex/contrib/layer_norm
#   copying apex/contrib/layer_norm/layer_norm.py -> build/lib/apex/contrib/layer_norm
#   copying apex/contrib/layer_norm/__init__.py -> build/lib/apex/contrib/layer_norm
#   creating build/lib/apex/amp/lists
#   copying apex/amp/lists/tensor_overrides.py -> build/lib/apex/amp/lists
#   copying apex/amp/lists/__init__.py -> build/lib/apex/amp/lists
#   copying apex/amp/lists/functional_overrides.py -> build/lib/apex/amp/lists
#   copying apex/amp/lists/torch_overrides.py -> build/lib/apex/amp/lists
#   creating build/lib/apex/pyprof/prof
#   copying apex/pyprof/prof/reduction.py -> build/lib/apex/pyprof/prof
#   copying apex/pyprof/prof/loss.py -> build/lib/apex/pyprof/prof
#   copying apex/pyprof/prof/utility.py -> build/lib/apex/pyprof/prof
#   copying apex/pyprof/prof/pointwise.py -> build/lib/apex/pyprof/prof
#   copying apex/pyprof/prof/output.py -> build/lib/apex/pyprof/prof
#   copying apex/pyprof/prof/usage.py -> build/lib/apex/pyprof/prof
#   copying apex/pyprof/prof/__main__.py -> build/lib/apex/pyprof/prof
#   copying apex/pyprof/prof/dropout.py -> build/lib/apex/pyprof/prof
#   copying apex/pyprof/prof/index_slice_join_mutate.py -> build/lib/apex/pyprof/prof
#   copying apex/pyprof/prof/convert.py -> build/lib/apex/pyprof/prof
#   copying apex/pyprof/prof/base.py -> build/lib/apex/pyprof/prof
#   copying apex/pyprof/prof/normalization.py -> build/lib/apex/pyprof/prof
#   copying apex/pyprof/prof/embedding.py -> build/lib/apex/pyprof/prof
#   copying apex/pyprof/prof/__init__.py -> build/lib/apex/pyprof/prof
#   copying apex/pyprof/prof/softmax.py -> build/lib/apex/pyprof/prof
#   copying apex/pyprof/prof/pooling.py -> build/lib/apex/pyprof/prof
#   copying apex/pyprof/prof/conv.py -> build/lib/apex/pyprof/prof
#   copying apex/pyprof/prof/prof.py -> build/lib/apex/pyprof/prof
#   copying apex/pyprof/prof/optim.py -> build/lib/apex/pyprof/prof
#   copying apex/pyprof/prof/data.py -> build/lib/apex/pyprof/prof
#   copying apex/pyprof/prof/recurrentCell.py -> build/lib/apex/pyprof/prof
#   copying apex/pyprof/prof/randomSample.py -> build/lib/apex/pyprof/prof
#   copying apex/pyprof/prof/linear.py -> build/lib/apex/pyprof/prof
#   copying apex/pyprof/prof/activation.py -> build/lib/apex/pyprof/prof
#   copying apex/pyprof/prof/blas.py -> build/lib/apex/pyprof/prof
#   copying apex/pyprof/prof/misc.py -> build/lib/apex/pyprof/prof
#   creating build/lib/apex/pyprof/nvtx
#   copying apex/pyprof/nvtx/__init__.py -> build/lib/apex/pyprof/nvtx
#   copying apex/pyprof/nvtx/nvmarker.py -> build/lib/apex/pyprof/nvtx
#   creating build/lib/apex/pyprof/parse
#   copying apex/pyprof/parse/db.py -> build/lib/apex/pyprof/parse
#   copying apex/pyprof/parse/__main__.py -> build/lib/apex/pyprof/parse
#   copying apex/pyprof/parse/__init__.py -> build/lib/apex/pyprof/parse
#   copying apex/pyprof/parse/parse.py -> build/lib/apex/pyprof/parse
#   copying apex/pyprof/parse/nvvp.py -> build/lib/apex/pyprof/parse
#   copying apex/pyprof/parse/kernel.py -> build/lib/apex/pyprof/parse
#   installing to build/bdist.linux-x86_64/wheel
#   running install
#   running install_lib
#   creating build/bdist.linux-x86_64
#   creating build/bdist.linux-x86_64/wheel
#   creating build/bdist.linux-x86_64/wheel/apex
#   creating build/bdist.linux-x86_64/wheel/apex/RNN
#   copying build/lib/apex/RNN/__init__.py -> build/bdist.linux-x86_64/wheel/apex/RNN
#   copying build/lib/apex/RNN/cells.py -> build/bdist.linux-x86_64/wheel/apex/RNN
#   copying build/lib/apex/RNN/models.py -> build/bdist.linux-x86_64/wheel/apex/RNN
#   copying build/lib/apex/RNN/RNNBackend.py -> build/bdist.linux-x86_64/wheel/apex/RNN
#   creating build/bdist.linux-x86_64/wheel/apex/normalization
#   copying build/lib/apex/normalization/__init__.py -> build/bdist.linux-x86_64/wheel/apex/normalization
#   copying build/lib/apex/normalization/fused_layer_norm.py -> build/bdist.linux-x86_64/wheel/apex/normalization
#   creating build/bdist.linux-x86_64/wheel/apex/mlp
#   copying build/lib/apex/mlp/__init__.py -> build/bdist.linux-x86_64/wheel/apex/mlp
#   copying build/lib/apex/mlp/mlp.py -> build/bdist.linux-x86_64/wheel/apex/mlp
#   creating build/bdist.linux-x86_64/wheel/apex/contrib
#   creating build/bdist.linux-x86_64/wheel/apex/contrib/multihead_attn
#   copying build/lib/apex/contrib/multihead_attn/fast_self_multihead_attn_func.py -> build/bdist.linux-x86_64/wheel/apex/contrib/multihead_attn
#   copying build/lib/apex/contrib/multihead_attn/fast_self_multihead_attn_norm_add_func.py -> build/bdist.linux-x86_64/wheel/apex/contrib/multihead_attn
#   copying build/lib/apex/contrib/multihead_attn/__init__.py -> build/bdist.linux-x86_64/wheel/apex/contrib/multihead_attn
#   copying build/lib/apex/contrib/multihead_attn/self_multihead_attn_func.py -> build/bdist.linux-x86_64/wheel/apex/contrib/multihead_attn
#   copying build/lib/apex/contrib/multihead_attn/mask_softmax_dropout_func.py -> build/bdist.linux-x86_64/wheel/apex/contrib/multihead_attn
#   copying build/lib/apex/contrib/multihead_attn/encdec_multihead_attn_func.py -> build/bdist.linux-x86_64/wheel/apex/contrib/multihead_attn
#   copying build/lib/apex/contrib/multihead_attn/fast_encdec_multihead_attn_func.py -> build/bdist.linux-x86_64/wheel/apex/contrib/multihead_attn
#   copying build/lib/apex/contrib/multihead_attn/encdec_multihead_attn.py -> build/bdist.linux-x86_64/wheel/apex/contrib/multihead_attn
#   copying build/lib/apex/contrib/multihead_attn/self_multihead_attn.py -> build/bdist.linux-x86_64/wheel/apex/contrib/multihead_attn
#   copying build/lib/apex/contrib/multihead_attn/fast_encdec_multihead_attn_norm_add_func.py -> build/bdist.linux-x86_64/wheel/apex/contrib/multihead_attn
#   creating build/bdist.linux-x86_64/wheel/apex/contrib/sparsity
#   copying build/lib/apex/contrib/sparsity/sparse_masklib.py -> build/bdist.linux-x86_64/wheel/apex/contrib/sparsity
#   copying build/lib/apex/contrib/sparsity/__init__.py -> build/bdist.linux-x86_64/wheel/apex/contrib/sparsity
#   copying build/lib/apex/contrib/sparsity/asp.py -> build/bdist.linux-x86_64/wheel/apex/contrib/sparsity
#   copying build/lib/apex/contrib/__init__.py -> build/bdist.linux-x86_64/wheel/apex/contrib
#   creating build/bdist.linux-x86_64/wheel/apex/contrib/optimizers
#   copying build/lib/apex/contrib/optimizers/fused_lamb.py -> build/bdist.linux-x86_64/wheel/apex/contrib/optimizers
#   copying build/lib/apex/contrib/optimizers/fused_sgd.py -> build/bdist.linux-x86_64/wheel/apex/contrib/optimizers
#   copying build/lib/apex/contrib/optimizers/distributed_fused_lamb.py -> build/bdist.linux-x86_64/wheel/apex/contrib/optimizers
#   copying build/lib/apex/contrib/optimizers/__init__.py -> build/bdist.linux-x86_64/wheel/apex/contrib/optimizers
#   copying build/lib/apex/contrib/optimizers/fp16_optimizer.py -> build/bdist.linux-x86_64/wheel/apex/contrib/optimizers
#   copying build/lib/apex/contrib/optimizers/distributed_fused_adam_v2.py -> build/bdist.linux-x86_64/wheel/apex/contrib/optimizers
#   copying build/lib/apex/contrib/optimizers/fused_adam.py -> build/bdist.linux-x86_64/wheel/apex/contrib/optimizers
#   copying build/lib/apex/contrib/optimizers/distributed_fused_adam.py -> build/bdist.linux-x86_64/wheel/apex/contrib/optimizers
#   copying build/lib/apex/contrib/optimizers/distributed_fused_adam_v3.py -> build/bdist.linux-x86_64/wheel/apex/contrib/optimizers
#   creating build/bdist.linux-x86_64/wheel/apex/contrib/transducer
#   copying build/lib/apex/contrib/transducer/__init__.py -> build/bdist.linux-x86_64/wheel/apex/contrib/transducer
#   copying build/lib/apex/contrib/transducer/transducer.py -> build/bdist.linux-x86_64/wheel/apex/contrib/transducer
#   creating build/bdist.linux-x86_64/wheel/apex/contrib/groupbn
#   copying build/lib/apex/contrib/groupbn/batch_norm.py -> build/bdist.linux-x86_64/wheel/apex/contrib/groupbn
#   copying build/lib/apex/contrib/groupbn/__init__.py -> build/bdist.linux-x86_64/wheel/apex/contrib/groupbn
#   creating build/bdist.linux-x86_64/wheel/apex/contrib/xentropy
#   copying build/lib/apex/contrib/xentropy/__init__.py -> build/bdist.linux-x86_64/wheel/apex/contrib/xentropy
#   copying build/lib/apex/contrib/xentropy/softmax_xentropy.py -> build/bdist.linux-x86_64/wheel/apex/contrib/xentropy
#   creating build/bdist.linux-x86_64/wheel/apex/contrib/layer_norm
#   copying build/lib/apex/contrib/layer_norm/layer_norm.py -> build/bdist.linux-x86_64/wheel/apex/contrib/layer_norm
#   copying build/lib/apex/contrib/layer_norm/__init__.py -> build/bdist.linux-x86_64/wheel/apex/contrib/layer_norm
#   creating build/bdist.linux-x86_64/wheel/apex/amp
#   copying build/lib/apex/amp/_initialize.py -> build/bdist.linux-x86_64/wheel/apex/amp
#   creating build/bdist.linux-x86_64/wheel/apex/amp/lists
#   copying build/lib/apex/amp/lists/tensor_overrides.py -> build/bdist.linux-x86_64/wheel/apex/amp/lists
#   copying build/lib/apex/amp/lists/__init__.py -> build/bdist.linux-x86_64/wheel/apex/amp/lists
#   copying build/lib/apex/amp/lists/functional_overrides.py -> build/bdist.linux-x86_64/wheel/apex/amp/lists
#   copying build/lib/apex/amp/lists/torch_overrides.py -> build/bdist.linux-x86_64/wheel/apex/amp/lists
#   copying build/lib/apex/amp/amp.py -> build/bdist.linux-x86_64/wheel/apex/amp
#   copying build/lib/apex/amp/opt.py -> build/bdist.linux-x86_64/wheel/apex/amp
#   copying build/lib/apex/amp/__init__.py -> build/bdist.linux-x86_64/wheel/apex/amp
#   copying build/lib/apex/amp/_amp_state.py -> build/bdist.linux-x86_64/wheel/apex/amp
#   copying build/lib/apex/amp/_process_optimizer.py -> build/bdist.linux-x86_64/wheel/apex/amp
#   copying build/lib/apex/amp/compat.py -> build/bdist.linux-x86_64/wheel/apex/amp
#   copying build/lib/apex/amp/utils.py -> build/bdist.linux-x86_64/wheel/apex/amp
#   copying build/lib/apex/amp/__version__.py -> build/bdist.linux-x86_64/wheel/apex/amp
#   copying build/lib/apex/amp/wrap.py -> build/bdist.linux-x86_64/wheel/apex/amp
#   copying build/lib/apex/amp/handle.py -> build/bdist.linux-x86_64/wheel/apex/amp
#   copying build/lib/apex/amp/rnn_compat.py -> build/bdist.linux-x86_64/wheel/apex/amp
#   copying build/lib/apex/amp/scaler.py -> build/bdist.linux-x86_64/wheel/apex/amp
#   copying build/lib/apex/amp/frontend.py -> build/bdist.linux-x86_64/wheel/apex/amp
#   copying build/lib/apex/__init__.py -> build/bdist.linux-x86_64/wheel/apex
#   creating build/bdist.linux-x86_64/wheel/apex/optimizers
#   copying build/lib/apex/optimizers/fused_lamb.py -> build/bdist.linux-x86_64/wheel/apex/optimizers
#   copying build/lib/apex/optimizers/fused_sgd.py -> build/bdist.linux-x86_64/wheel/apex/optimizers
#   copying build/lib/apex/optimizers/fused_novograd.py -> build/bdist.linux-x86_64/wheel/apex/optimizers
#   copying build/lib/apex/optimizers/__init__.py -> build/bdist.linux-x86_64/wheel/apex/optimizers
#   copying build/lib/apex/optimizers/fused_adagrad.py -> build/bdist.linux-x86_64/wheel/apex/optimizers
#   copying build/lib/apex/optimizers/fused_adam.py -> build/bdist.linux-x86_64/wheel/apex/optimizers
#   creating build/bdist.linux-x86_64/wheel/apex/pyprof
#   creating build/bdist.linux-x86_64/wheel/apex/pyprof/prof
#   copying build/lib/apex/pyprof/prof/reduction.py -> build/bdist.linux-x86_64/wheel/apex/pyprof/prof
#   copying build/lib/apex/pyprof/prof/loss.py -> build/bdist.linux-x86_64/wheel/apex/pyprof/prof
#   copying build/lib/apex/pyprof/prof/utility.py -> build/bdist.linux-x86_64/wheel/apex/pyprof/prof
#   copying build/lib/apex/pyprof/prof/pointwise.py -> build/bdist.linux-x86_64/wheel/apex/pyprof/prof
#   copying build/lib/apex/pyprof/prof/output.py -> build/bdist.linux-x86_64/wheel/apex/pyprof/prof
#   copying build/lib/apex/pyprof/prof/usage.py -> build/bdist.linux-x86_64/wheel/apex/pyprof/prof
#   copying build/lib/apex/pyprof/prof/__main__.py -> build/bdist.linux-x86_64/wheel/apex/pyprof/prof
#   copying build/lib/apex/pyprof/prof/dropout.py -> build/bdist.linux-x86_64/wheel/apex/pyprof/prof
#   copying build/lib/apex/pyprof/prof/index_slice_join_mutate.py -> build/bdist.linux-x86_64/wheel/apex/pyprof/prof
#   copying build/lib/apex/pyprof/prof/convert.py -> build/bdist.linux-x86_64/wheel/apex/pyprof/prof
#   copying build/lib/apex/pyprof/prof/base.py -> build/bdist.linux-x86_64/wheel/apex/pyprof/prof
#   copying build/lib/apex/pyprof/prof/normalization.py -> build/bdist.linux-x86_64/wheel/apex/pyprof/prof
#   copying build/lib/apex/pyprof/prof/embedding.py -> build/bdist.linux-x86_64/wheel/apex/pyprof/prof
#   copying build/lib/apex/pyprof/prof/__init__.py -> build/bdist.linux-x86_64/wheel/apex/pyprof/prof
#   copying build/lib/apex/pyprof/prof/softmax.py -> build/bdist.linux-x86_64/wheel/apex/pyprof/prof
#   copying build/lib/apex/pyprof/prof/pooling.py -> build/bdist.linux-x86_64/wheel/apex/pyprof/prof
#   copying build/lib/apex/pyprof/prof/conv.py -> build/bdist.linux-x86_64/wheel/apex/pyprof/prof
#   copying build/lib/apex/pyprof/prof/prof.py -> build/bdist.linux-x86_64/wheel/apex/pyprof/prof
#   copying build/lib/apex/pyprof/prof/optim.py -> build/bdist.linux-x86_64/wheel/apex/pyprof/prof
#   copying build/lib/apex/pyprof/prof/data.py -> build/bdist.linux-x86_64/wheel/apex/pyprof/prof
#   copying build/lib/apex/pyprof/prof/recurrentCell.py -> build/bdist.linux-x86_64/wheel/apex/pyprof/prof
#   copying build/lib/apex/pyprof/prof/randomSample.py -> build/bdist.linux-x86_64/wheel/apex/pyprof/prof
#   copying build/lib/apex/pyprof/prof/linear.py -> build/bdist.linux-x86_64/wheel/apex/pyprof/prof
#   copying build/lib/apex/pyprof/prof/activation.py -> build/bdist.linux-x86_64/wheel/apex/pyprof/prof
#   copying build/lib/apex/pyprof/prof/blas.py -> build/bdist.linux-x86_64/wheel/apex/pyprof/prof
#   copying build/lib/apex/pyprof/prof/misc.py -> build/bdist.linux-x86_64/wheel/apex/pyprof/prof
#   copying build/lib/apex/pyprof/__init__.py -> build/bdist.linux-x86_64/wheel/apex/pyprof
#   creating build/bdist.linux-x86_64/wheel/apex/pyprof/nvtx
#   copying build/lib/apex/pyprof/nvtx/__init__.py -> build/bdist.linux-x86_64/wheel/apex/pyprof/nvtx
#   copying build/lib/apex/pyprof/nvtx/nvmarker.py -> build/bdist.linux-x86_64/wheel/apex/pyprof/nvtx
#   creating build/bdist.linux-x86_64/wheel/apex/pyprof/parse
#   copying build/lib/apex/pyprof/parse/db.py -> build/bdist.linux-x86_64/wheel/apex/pyprof/parse
#   copying build/lib/apex/pyprof/parse/__main__.py -> build/bdist.linux-x86_64/wheel/apex/pyprof/parse
#   copying build/lib/apex/pyprof/parse/__init__.py -> build/bdist.linux-x86_64/wheel/apex/pyprof/parse
#   copying build/lib/apex/pyprof/parse/parse.py -> build/bdist.linux-x86_64/wheel/apex/pyprof/parse
#   copying build/lib/apex/pyprof/parse/nvvp.py -> build/bdist.linux-x86_64/wheel/apex/pyprof/parse
#   copying build/lib/apex/pyprof/parse/kernel.py -> build/bdist.linux-x86_64/wheel/apex/pyprof/parse
#   creating build/bdist.linux-x86_64/wheel/apex/parallel
#   copying build/lib/apex/parallel/sync_batchnorm.py -> build/bdist.linux-x86_64/wheel/apex/parallel
#   copying build/lib/apex/parallel/optimized_sync_batchnorm.py -> build/bdist.linux-x86_64/wheel/apex/parallel
#   copying build/lib/apex/parallel/LARC.py -> build/bdist.linux-x86_64/wheel/apex/parallel
#   copying build/lib/apex/parallel/sync_batchnorm_kernel.py -> build/bdist.linux-x86_64/wheel/apex/parallel
#   copying build/lib/apex/parallel/multiproc.py -> build/bdist.linux-x86_64/wheel/apex/parallel
#   copying build/lib/apex/parallel/__init__.py -> build/bdist.linux-x86_64/wheel/apex/parallel
#   copying build/lib/apex/parallel/optimized_sync_batchnorm_kernel.py -> build/bdist.linux-x86_64/wheel/apex/parallel
#   copying build/lib/apex/parallel/distributed.py -> build/bdist.linux-x86_64/wheel/apex/parallel
#   creating build/bdist.linux-x86_64/wheel/apex/multi_tensor_apply
#   copying build/lib/apex/multi_tensor_apply/__init__.py -> build/bdist.linux-x86_64/wheel/apex/multi_tensor_apply
#   copying build/lib/apex/multi_tensor_apply/multi_tensor_apply.py -> build/bdist.linux-x86_64/wheel/apex/multi_tensor_apply
#   creating build/bdist.linux-x86_64/wheel/apex/reparameterization
#   copying build/lib/apex/reparameterization/reparameterization.py -> build/bdist.linux-x86_64/wheel/apex/reparameterization
#   copying build/lib/apex/reparameterization/__init__.py -> build/bdist.linux-x86_64/wheel/apex/reparameterization
#   copying build/lib/apex/reparameterization/weight_norm.py -> build/bdist.linux-x86_64/wheel/apex/reparameterization
#   creating build/bdist.linux-x86_64/wheel/apex/fp16_utils
#   copying build/lib/apex/fp16_utils/loss_scaler.py -> build/bdist.linux-x86_64/wheel/apex/fp16_utils
#   copying build/lib/apex/fp16_utils/__init__.py -> build/bdist.linux-x86_64/wheel/apex/fp16_utils
#   copying build/lib/apex/fp16_utils/fp16_optimizer.py -> build/bdist.linux-x86_64/wheel/apex/fp16_utils
#   copying build/lib/apex/fp16_utils/fp16util.py -> build/bdist.linux-x86_64/wheel/apex/fp16_utils
#   running install_egg_info
#   running egg_info
#   creating apex.egg-info
#   writing apex.egg-info/PKG-INFO
#   writing dependency_links to apex.egg-info/dependency_links.txt
#   writing top-level names to apex.egg-info/top_level.txt
#   writing manifest file 'apex.egg-info/SOURCES.txt'
#   writing manifest file 'apex.egg-info/SOURCES.txt'
#   Copying apex.egg-info to build/bdist.linux-x86_64/wheel/apex-0.1-py3.7.egg-info
#   running install_scripts
#   adding license file "LICENSE" (matched pattern "LICEN[CS]E*")
#   creating build/bdist.linux-x86_64/wheel/apex-0.1.dist-info/WHEEL
#   creating '/tmp/pip-wheel-mkxke5vv/apex-0.1-cp37-none-any.whl' and adding 'build/bdist.linux-x86_64/wheel' to it
#   adding 'apex/__init__.py'
#   adding 'apex/RNN/RNNBackend.py'
#   adding 'apex/RNN/__init__.py'
#   adding 'apex/RNN/cells.py'
#   adding 'apex/RNN/models.py'
#   adding 'apex/amp/__init__.py'
#   adding 'apex/amp/__version__.py'
#   adding 'apex/amp/_amp_state.py'
#   adding 'apex/amp/_initialize.py'
#   adding 'apex/amp/_process_optimizer.py'
#   adding 'apex/amp/amp.py'
#   adding 'apex/amp/compat.py'
#   adding 'apex/amp/frontend.py'
#   adding 'apex/amp/handle.py'
#   adding 'apex/amp/opt.py'
#   adding 'apex/amp/rnn_compat.py'
#   adding 'apex/amp/scaler.py'
#   adding 'apex/amp/utils.py'
#   adding 'apex/amp/wrap.py'
#   adding 'apex/amp/lists/__init__.py'
#   adding 'apex/amp/lists/functional_overrides.py'
#   adding 'apex/amp/lists/tensor_overrides.py'
#   adding 'apex/amp/lists/torch_overrides.py'
#   adding 'apex/contrib/__init__.py'
#   adding 'apex/contrib/groupbn/__init__.py'
#   adding 'apex/contrib/groupbn/batch_norm.py'
#   adding 'apex/contrib/layer_norm/__init__.py'
#   adding 'apex/contrib/layer_norm/layer_norm.py'
#   adding 'apex/contrib/multihead_attn/__init__.py'
#   adding 'apex/contrib/multihead_attn/encdec_multihead_attn.py'
#   adding 'apex/contrib/multihead_attn/encdec_multihead_attn_func.py'
#   adding 'apex/contrib/multihead_attn/fast_encdec_multihead_attn_func.py'
#   adding 'apex/contrib/multihead_attn/fast_encdec_multihead_attn_norm_add_func.py'
#   adding 'apex/contrib/multihead_attn/fast_self_multihead_attn_func.py'
#   adding 'apex/contrib/multihead_attn/fast_self_multihead_attn_norm_add_func.py'
#   adding 'apex/contrib/multihead_attn/mask_softmax_dropout_func.py'
#   adding 'apex/contrib/multihead_attn/self_multihead_attn.py'
#   adding 'apex/contrib/multihead_attn/self_multihead_attn_func.py'
#   adding 'apex/contrib/optimizers/__init__.py'
#   adding 'apex/contrib/optimizers/distributed_fused_adam.py'
#   adding 'apex/contrib/optimizers/distributed_fused_adam_v2.py'
#   adding 'apex/contrib/optimizers/distributed_fused_adam_v3.py'
#   adding 'apex/contrib/optimizers/distributed_fused_lamb.py'
#   adding 'apex/contrib/optimizers/fp16_optimizer.py'
#   adding 'apex/contrib/optimizers/fused_adam.py'
#   adding 'apex/contrib/optimizers/fused_lamb.py'
#   adding 'apex/contrib/optimizers/fused_sgd.py'
#   adding 'apex/contrib/sparsity/__init__.py'
#   adding 'apex/contrib/sparsity/asp.py'
#   adding 'apex/contrib/sparsity/sparse_masklib.py'
#   adding 'apex/contrib/transducer/__init__.py'
#   adding 'apex/contrib/transducer/transducer.py'
#   adding 'apex/contrib/xentropy/__init__.py'
#   adding 'apex/contrib/xentropy/softmax_xentropy.py'
#   adding 'apex/fp16_utils/__init__.py'
#   adding 'apex/fp16_utils/fp16_optimizer.py'
#   adding 'apex/fp16_utils/fp16util.py'
#   adding 'apex/fp16_utils/loss_scaler.py'
#   adding 'apex/mlp/__init__.py'
#   adding 'apex/mlp/mlp.py'
#   adding 'apex/multi_tensor_apply/__init__.py'
#   adding 'apex/multi_tensor_apply/multi_tensor_apply.py'
#   adding 'apex/normalization/__init__.py'
#   adding 'apex/normalization/fused_layer_norm.py'
#   adding 'apex/optimizers/__init__.py'
#   adding 'apex/optimizers/fused_adagrad.py'
#   adding 'apex/optimizers/fused_adam.py'
#   adding 'apex/optimizers/fused_lamb.py'
#   adding 'apex/optimizers/fused_novograd.py'
#   adding 'apex/optimizers/fused_sgd.py'
#   adding 'apex/parallel/LARC.py'
#   adding 'apex/parallel/__init__.py'
#   adding 'apex/parallel/distributed.py'
#   adding 'apex/parallel/multiproc.py'
#   adding 'apex/parallel/optimized_sync_batchnorm.py'
#   adding 'apex/parallel/optimized_sync_batchnorm_kernel.py'
#   adding 'apex/parallel/sync_batchnorm.py'
#   adding 'apex/parallel/sync_batchnorm_kernel.py'
#   adding 'apex/pyprof/__init__.py'
#   adding 'apex/pyprof/nvtx/__init__.py'
#   adding 'apex/pyprof/nvtx/nvmarker.py'
#   adding 'apex/pyprof/parse/__init__.py'
#   adding 'apex/pyprof/parse/__main__.py'
#   adding 'apex/pyprof/parse/db.py'
#   adding 'apex/pyprof/parse/kernel.py'
#   adding 'apex/pyprof/parse/nvvp.py'
#   adding 'apex/pyprof/parse/parse.py'
#   adding 'apex/pyprof/prof/__init__.py'
#   adding 'apex/pyprof/prof/__main__.py'
#   adding 'apex/pyprof/prof/activation.py'
#   adding 'apex/pyprof/prof/base.py'
#   adding 'apex/pyprof/prof/blas.py'
#   adding 'apex/pyprof/prof/conv.py'
#   adding 'apex/pyprof/prof/convert.py'
#   adding 'apex/pyprof/prof/data.py'
#   adding 'apex/pyprof/prof/dropout.py'
#   adding 'apex/pyprof/prof/embedding.py'
#   adding 'apex/pyprof/prof/index_slice_join_mutate.py'
#   adding 'apex/pyprof/prof/linear.py'
#   adding 'apex/pyprof/prof/loss.py'
#   adding 'apex/pyprof/prof/misc.py'
#   adding 'apex/pyprof/prof/normalization.py'
#   adding 'apex/pyprof/prof/optim.py'
#   adding 'apex/pyprof/prof/output.py'
#   adding 'apex/pyprof/prof/pointwise.py'
#   adding 'apex/pyprof/prof/pooling.py'
#   adding 'apex/pyprof/prof/prof.py'
#   adding 'apex/pyprof/prof/randomSample.py'
#   adding 'apex/pyprof/prof/recurrentCell.py'
#   adding 'apex/pyprof/prof/reduction.py'
#   adding 'apex/pyprof/prof/softmax.py'
#   adding 'apex/pyprof/prof/usage.py'
#   adding 'apex/pyprof/prof/utility.py'
#   adding 'apex/reparameterization/__init__.py'
#   adding 'apex/reparameterization/reparameterization.py'
#   adding 'apex/reparameterization/weight_norm.py'
#   adding 'apex-0.1.dist-info/LICENSE'
#   adding 'apex-0.1.dist-info/METADATA'
#   adding 'apex-0.1.dist-info/WHEEL'
#   adding 'apex-0.1.dist-info/top_level.txt'
#   adding 'apex-0.1.dist-info/RECORD'
#   removing build/bdist.linux-x86_64/wheel
# done
#   Created wheel for apex: filename=apex-0.1-cp37-none-any.whl size=198540 sha256=8642e8e95f8d012c58c3ee4858e7d9c3662ef6cdbe140705870a37dc809d830b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-xd_ed1xp/wheels/b1/3a/aa/d84906eaab780ae580c7a5686a33bf2820d8590ac3b60d5967
#   Removing source in /tmp/pip-req-build-kksoyrx5
# Successfully built apex
# Installing collected packages: apex
#
# Successfully installed apex-0.1
# Cleaning up...
# Removed build tracker '/tmp/pip-req-tracker-7u4k5omj'
# /content
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Collecting transformers
#   Downloading https://files.pythonhosted.org/packages/81/91/61d69d58a1af1bd81d9ca9d62c90a6de3ab80d77f27c5df65d9a2c1f5626/transformers-4.5.0-py3-none-any.whl (2.1MB)
#      |████████████████████████████████| 2.2MB 5.7MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.41.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers) (3.8.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers) (20.9)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.0.12)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading https://files.pythonhosted.org/packages/ae/04/5b870f26a858552025a62f1649c20d29d2672c02ff3c3fb4c688ca46467a/tokenizers-0.10.2-cp37-cp37m-manylinux2010_x86_64.whl (3.3MB)
#      |████████████████████████████████| 3.3MB 22.1MB/s
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/08/cd/342e584ee544d044fb573ae697404ce22ede086c9e87ce5960772084cad0/sacremoses-0.0.44.tar.gz (862kB)
#      |████████████████████████████████| 870kB 42.4MB/s
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.4.1)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.7.4.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.0.1)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.44-cp37-none-any.whl size=886084 sha256=5aaca0e73426cf787953f232f262b2e08787809b447ee0ca10040a8f3230d613
#   Stored in directory: /root/.cache/pip/wheels/3e/fb/c0/13ab4d63d537658f448366744654323077c4d90069b6512f3c
# Successfully built sacremoses
# Installing collected packages: tokenizers, sacremoses, transformers
# Successfully installed sacremoses-0.0.44 tokenizers-0.10.2 transformers-4.5.0
# Collecting sentencepiece
#   Downloading https://files.pythonhosted.org/packages/f5/99/e0808cb947ba10f575839c43e8fafc9cc44e4a7a2c8f79c60db48220a577/sentencepiece-0.1.95-cp37-cp37m-manylinux2014_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 4.5MB/s
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.95

# %% [markdown]
# # ALBERT Transformer

# %% [markdown]
# ## ALBERT Pre-Trained Tokenizers

# %%
def tokenization(): 
    tokenizer = AlbertTokenizer.from_pretrained('albert-base-v2')
    return tokenizer

# %% [markdown]
# ## ALBERT Pre-Trained Model

# %%
def race_model():
    config = AlbertConfig.from_pretrained('albert-base-v2', num_labels=4)
    model = AlbertForMultipleChoice.from_pretrained('albert-base-v2', config=config)
    return model

# %% [markdown]
# # RACE Dataset

# %% [markdown]
# ## RACE Feature Class

# %%
class raceFeatures(object):
    def __init__(self,
                 example_id,
                 choices_features,
                 label):
        self.example_id = example_id
        self.choices_features = [
            {
                'input_ids': input_ids,
                'segment_ids': segment_ids,
                'input_mask': input_mask
            }
            for _, input_ids, segment_ids, input_mask in choices_features
        ]
        self.label = label

# %% [markdown]
# ## RACE Object Class

# %%
class race(object):
    def __init__(self,
                 test_id,
                 article,
                 start_ending,
                 ending_0,
                 ending_1,
                 ending_2,
                 ending_3,
                 label):
        self.test_id = test_id
        self.article = article
        self.start_ending = start_ending
        self.endings = [
                 ending_0,
                 ending_1,
                 ending_2,
                 ending_3,
        ]
        self.label = label

    def __str__(self):
        return self.__repr__()

    def __repr__(self):
        l = [
            "id: {}".format(self.test_id),
            "article: {}".format(self.article),
            "question: {}".format(self.start_ending),
            "option_0: {}".format(self.endings[0]),
            "option_1: {}".format(self.endings[1]),
            "option_2: {}".format(self.endings[2]),
            "option_3: {}".format(self.endings[3]),
        ]


        if self.label is not None:
            l.append("label: {}".format(self.label))

        return ", ".join(l)

# %% [markdown]
# ## Prepare RACE data

# %%
def race_trian():
    paths = [
             "/content/RACE/RACE/train/middle",
             "/content/RACE/RACE/train/high"
    ]
    examples = []
    for path in paths:
        filenames = glob.glob(path+"/*txt")
        for filename in filenames:
          with open(filename, 'r', encoding='utf-8') as fpr:
            data_raw = json.load(fpr)
            article = data_raw["article"]
            for i in range(len(data_raw["answers"])):
              truth = ord(data_raw['answers'][i]) - ord('A')
              question = data_raw['questions'][i]
              options = data_raw['options'][i]
              examples.append(
                  race(
                      test_id = filename+'-'+str(i),
                      article = article,
                      start_ending = question,
                      ending_0 = options[0],
                      ending_1 = options[1],
                      ending_2 = options[2],
                      ending_3 = options[3],
                      label = truth
                  )
              )        
    return examples


def race_dev():
    paths = [
             "/content/RACE/RACE/dev/middle",
             "/content/RACE/RACE/dev/high"
    ]
    examples = []
    for path in paths:
        filenames = glob.glob(path+"/*txt")
        for filename in filenames:
            with open(filename, 'r', encoding='utf-8') as fpr:
                data_raw = json.load(fpr)
                article = data_raw["article"]
                for i in range(len(data_raw["answers"])):
                    truth = ord(data_raw['answers'][i]) - ord('A')
                    question = data_raw['questions'][i]
                    options = data_raw['options'][i]
                    examples.append(
                        race(
                            test_id = filename+'-'+str(i),
                            article = article,
                            start_ending = question,
                            ending_0 = options[0],
                            ending_1 = options[1],
                            ending_2 = options[2],
                            ending_3 = options[3],
                            label = truth
                        )
                    )
                    
    return examples

def race_test():
    paths = [
             "/content/RACE/RACE/test/middle",
             "/content/RACE/RACE/test/high"
    ]
    examples = []
    for path in paths:
        filenames = glob.glob(path+"/*txt")
        for filename in filenames:
            with open(filename, 'r', encoding='utf-8') as fpr:
                data_raw = json.load(fpr)
                article = data_raw["article"]
                for i in range(len(data_raw["answers"])):
                    truth = ord(data_raw['answers'][i]) - ord('A')
                    question = data_raw['questions'][i]
                    options = data_raw['options'][i]
                    examples.append(
                        race(
                            test_id = filename+'-'+str(i),
                            article = article,
                            start_ending = question,
                            ending_0 = options[0],
                            ending_1 = options[1],
                            ending_2 = options[2],
                            ending_3 = options[3],
                            label = truth
                        )
                    )
                    
    return examples

# %% [markdown]
# ## RACE Dataset

# %%
def raceDataSet(tokenizer, task_type, max_seq_length):
    examples = None
    if task_type == "train":
        examples = race_trian()
    elif task_type == "dev":
        examples = race_dev()
    elif task_type == "test":
        examples = race_test()
        
    features = []
    for example_index, example in enumerate(examples):
        # article tokens
        article_tokens = tokenizer.tokenize(example.article)
        # quesiton tokens
        start_ending_tokens = tokenizer.tokenize(example.start_ending)

        choices_features = []
        for ending_index, ending in enumerate(example.endings):
            article_tokens_choice = article_tokens[:]

            ending_tokens = start_ending_tokens + ["[SEP]"] + tokenizer.tokenize(ending)
            # ending_tokens = start_ending_tokens + tokenizer.tokenize(ending)

            encode = tokenizer.encode_plus(article_tokens_choice, 
                                           ending_tokens,
                                           add_special_tokens=True,
                                           padding='max_length',
                                           truncation=True,
                                           max_length=max_seq_length)
            
            input_ids = encode["input_ids"]
            segments_ids = encode["token_type_ids"]
            input_mask = encode["attention_mask"]
            tokens = tokenizer.decode(input_ids)

            assert len(input_ids) == max_seq_length
            assert len(input_mask) == max_seq_length
            assert len(segments_ids) == max_seq_length

            choices_features.append((tokens, input_ids, segments_ids, input_mask))

        label = example.label
        features.append(raceFeatures(
            example_id=example.test_id,
            choices_features=choices_features,
            label=label
        ))

    tensor_input_ids = torch.tensor([[choice["input_ids"] for choice in feature.choices_features] for feature in features], dtype=torch.long)
    tensor_segment_ids = torch.tensor([[choice["segment_ids"] for choice in feature.choices_features] for feature in features], dtype=torch.long)
    tensor_input_mask = torch.tensor([[choice["input_mask"] for choice in feature.choices_features] for feature in features], dtype=torch.long)
    tensor_labels = torch.tensor([f.label for f in features], dtype=torch.long)   
    tensor_dataset = TensorDataset(tensor_input_ids, tensor_segment_ids, tensor_input_mask, tensor_labels)  
      
    if task_type == "test":
      new_test_data = []
      for i in tensor_dataset:
        new_input_ids = i[0]
        new_segment_ids = i[1]
        new_input_masks = i[2]
        new_test_data.append([new_input_ids, new_segment_ids, new_input_masks])
      tensor_dataset = tuple(new_test_data)

    return tensor_dataset

# %% [markdown]
# # GPU configuration

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Training & Prediction

# %% [markdown]
# ## Prediction

# %%
def get_predictions(model, dataloader, compute_acc=False):
    predictions = None
    correct = 0
    total = 0
  
    with torch.no_grad():
        for data in dataloader:
            if next(model.parameters()).is_cuda:
                data = [t.to(device) for t in data if t is not None]
            
            tokens_tensors, segments_tensors, masks_tensors = data[:3]
            outputs = model(input_ids=tokens_tensors, 
                            token_type_ids=segments_tensors, 
                            attention_mask=masks_tensors)
            
            logits = outputs[0]
                        
            _, pred = torch.max(logits.data, 1)
            
            if compute_acc:
                labels = data[3]
                total += labels.size(0)
                correct += (pred == labels).sum().item()
                
            if predictions is None:
                predictions = pred
            else:
                predictions = torch.cat((predictions, pred))
    
    if compute_acc:
        acc = correct / total
        return predictions, acc
    return predictions

# %% [markdown]
# ## Run Race

# %%
BATCH = 16
MAX_SEQ_LEN = 128
LR = 2e-5

tokenizer = tokenization()
model = race_model()
model = model.to(device)

train_data = raceDataSet(tokenizer, "train", MAX_SEQ_LEN)
train_sampler = RandomSampler(train_data)
train_dataloader = DataLoader(train_data, sampler=train_sampler, batch_size=BATCH)
  
no_decay = ['bias', 'LayerNorm.weight']
optimizer_grouped_parameters = [
    {'params': [p for n, p in model.named_parameters() if not any(nd in n for nd in no_decay)], 'weight_decay': 0.01},
    {'params': [p for n, p in model.named_parameters() if any(nd in n for nd in no_decay)], 'weight_decay': 0.0}
]
adam_optimizer = AdamW(optimizer_grouped_parameters, lr=LR)
model, adam_optimizer = amp.initialize(model, adam_optimizer, opt_level="O1")
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=760289.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1312669.0, style=ProgressStyle(descript…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=684.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=47376696.0, style=ProgressStyle(descrip…
# Some weights of the model checkpoint at albert-base-v2 were not used when initializing AlbertForMultipleChoice: ['predictions.bias', 'predictions.LayerNorm.weight', 'predictions.LayerNorm.bias', 'predictions.dense.weight', 'predictions.dense.bias', 'predictions.decoder.weight', 'predictions.decoder.bias']
# - This IS expected if you are initializing AlbertForMultipleChoice from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing AlbertForMultipleChoice from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of AlbertForMultipleChoice were not initialized from the model checkpoint at albert-base-v2 and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Selected optimization level O1:  Insert automatic casts around Pytorch functions and Tensor methods.
#
# Defaults for this optimization level are:
# enabled                : True
# opt_level              : O1
# cast_model_type        : None
# patch_torch_functions  : True
# keep_batchnorm_fp32    : None
# master_weights         : None
# loss_scale             : dynamic
# Processing user overrides (additional kwargs that are not None)...
# After processing overrides, optimization options are:
# enabled                : True
# opt_level              : O1
# cast_model_type        : None
# patch_torch_functions  : True
# keep_batchnorm_fp32    : None
# master_weights         : None
# loss_scale             : dynamic
# Warning:  multi_tensor_applier fused unscale kernel is unavailable, possibly because apex was installed without --cuda_ext --cpp_ext. Using Python fallback.  Original ImportError was: ModuleNotFoundError("No module named 'amp_C'")

# %%
EPOCHS = 3

print("Start Training...")
for epoch in range(EPOCHS):
    epoch_start = time.time()
    train_loss = 0.0
    total_loss, batch_loss, batch_counts = 0, 0, 0
    model.train()
    for data in train_dataloader:
      tokens_tensors, segments_tensors, masks_tensors, labels_tensor = [t.to(device) for t in data]
      
      # Set the gradient to 0
      adam_optimizer.zero_grad()
      outputs = model(input_ids=tokens_tensors, 
                      token_type_ids=segments_tensors, 
                      attention_mask=masks_tensors, 
                      labels=labels_tensor)
      
      # print("outputs: {}".format(outputs))
      
      loss = outputs[0]
      
      train_loss += loss.item()  
      with amp.scale_loss(loss, adam_optimizer) as scaled_loss:
        scaled_loss.backward()
      adam_optimizer.step()

    # Calculating Accuracy
    _, train_accuracy = get_predictions(model, train_dataloader, compute_acc=True)

    ## Evaluation
    model.eval()    
    dev_data = raceDataSet(tokenizer=tokenizer, task_type="dev", max_seq_length=MAX_SEQ_LEN)
    dev_dataloader = DataLoader(dev_data, batch_size=BATCH)   
    # Tracking variables
    dev_accuracy = []
    dev_loss = []   
    eval_time_start = time.time()
    # For each batch in our validation set...
    for data in dev_dataloader:
        # Load batch to GPU
        tokens_tensors, segments_tensors, masks_tensors, labels_tensor = [t.to(device) for t in data]   
        # Compute logits
        with torch.no_grad():
          outputs = model(input_ids=tokens_tensors, 
                      token_type_ids=segments_tensors, 
                      attention_mask=masks_tensors, 
                      labels=labels_tensor)
        loss = outputs[0]
        logits = outputs[1]
        # Compute loss
        dev_loss.append(loss.item())    
        # Get the predictions
        preds = torch.argmax(logits, dim=1).flatten()   
        # Calculating Accuracy
    _, dev_acc = get_predictions(model, dev_dataloader, compute_acc=True)
    dev_accuracy.append(dev_acc)
    eval_time_stop = time.time()    
    # Compute the average accuracy and loss over the validation set.
    dev_loss = np.mean(dev_loss)
    dev_accuracy = np.mean(dev_accuracy)

    epoch_end = time.time()   
    print("Training Epoch: {}, TRAIN-Loss: {}, TRAIN-Accuracy: {}, DEV-Loss: {}, DEV-Accuracy: {},Epcoh Time: {}".
          format(epoch+1, train_loss, train_accuracy, dev_loss, dev_accuracy, epoch_end-epoch_start))

    # print('[epoch %d] loss: %.3f, acc: %.3f' % (epoch + 1, total_loss, acc))
    # print("Training Epoch: {}, Loss: {}, Accuracy: {}, Epcoh Time: {}".format(epoch+1, total_loss, acc, epDoch_end-epoch_start))
# Out:
# Start Training...
# Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 32768.0
# Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 16384.0
# Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 8192.0
# Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 4096.0
# Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 4096.0
# Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 2048.0
# Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 2048.0
# Training Epoch: 1, TRAIN-Loss: 6397.2468784451485, TRAIN-Accuracy: 0.5976942161928391, DEV-Loss: 1.073968795487304, DEV-Accuracy: 0.5316144874155924,Epcoh Time: 6471.994326353073
# Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 1024.0
# Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 1024.0
# Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 512.0
# Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 256.0
# Training Epoch: 2, TRAIN-Loss: 5350.7597097456455, TRAIN-Accuracy: 0.6944096692691143, DEV-Loss: 1.032799582271015, DEV-Accuracy: 0.5618989154900758,Epcoh Time: 6470.096781492233
# Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 512.0
# Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 256.0
# Training Epoch: 3, TRAIN-Loss: 4705.4342513382435, TRAIN-Accuracy: 0.7527598843693807, DEV-Loss: 1.0813585116582758, DEV-Accuracy: 0.5473705749948844,Epcoh Time: 6468.245429515839

# %% [markdown]
# ## Test Prediction

# %%
TEST_MAX_SEQ_LEN = 128
TEST_BATCH = 8

model.eval()
tokenizer = tokenization()

test_data = raceDataSet(tokenizer=tokenizer, task_type="test", max_seq_length=TEST_MAX_SEQ_LEN)

test_dataloader = DataLoader(test_data, batch_size=TEST_BATCH)

predictions = get_predictions(model, test_dataloader)

# %%
pred_labels = predictions.tolist()
print(pred_labels)

# %%
real_lables = []
for i in range(len(race_test())):
  real_lables.append(race_test()[i].label)

# %%
# Testing Result Evaluation
from sklearn.metrics import accuracy_score

print("Testing Accuracy: {}".format(accuracy_score(real_lables, pred_labels)))
# Out:
# Testing Accuracy: 0.5518848804215647
